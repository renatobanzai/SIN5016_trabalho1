# %%
import sys
import logging
import h5py
import cupy as cp
import numpy as np
import math
import random
import datetime
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

class dataprep:
    def __init__(self, hdf5_path, max_artists=-1, random_state=2, lbp=False):
        '''
        Inicia a classe
        :param hdf5_path: path com o arquivo hdf5 de origem
        :param random_state: seed para randomizar
        '''
        self.hdf5_path = hdf5_path
        self.random_state = random_state
        self.max_artists = max_artists
        self.lbp = lbp

    def load_hdf5(self, min_photos_by_artist=7):
        '''
        :return: numpy array com os artistas unicos
        '''
        f = h5py.File(self.hdf5_path, 'r')
        self.np_data = np.array(f['descriptor'])
        self.cp_data = cp.array(f['descriptor'])

        unique_artists, photos_by_artist = np.unique(self.np_data[:, 0], return_counts=True)

        unique_artists = unique_artists[photos_by_artist >= min_photos_by_artist]

        np.random.seed(self.random_state)

        np.random.shuffle(unique_artists)
        if self.max_artists > -1:
            unique_artists = unique_artists[:self.max_artists]

        self.unique_artists = unique_artists
        return self.unique_artists

    def get_dictionary_artists(self, list_unique_artists=[]):
        self.dict_artists = {}
        if not list_unique_artists:
            list_unique_artists = self.unique_artists

        for artist in list_unique_artists:
            # filtra os registros/fotografias de cada artista
            dataset = self.cp_data[cp.where(self.cp_data[:, 0] == artist)]
            # adiciona um tupla (x,y) por artista
            if self.lbp:
              self.dict_artists[artist] = (dataset[:,1:]/255, dataset[:,:1])
            else:
              self.dict_artists[artist] = (dataset[:,1:], dataset[:,:1])
        return self.dict_artists

    def get_dictionary_kfold_test(self, train_percent=0.8, k=5):
        self.kfolds = k
        self.dict_artists_kfold = {}
        self.dict_artists_test = {}
        self.dict_artists_train = {}
        folds_fotos = 0
        test_fotos = 0
        lost_artist = False
        for artist in self.dict_artists.keys():

            artist_photos = self.dict_artists[artist][0].shape[0]
            split_train = math.floor(artist_photos*train_percent)
            if split_train < 1 or artist_photos < 2:
                lost_artist = True
                logging.warning("artista {} nao possui registros suficientes para treino e teste.".format(artist))
            else:
                if split_train < k:
                    lost_artist = True
                    logging.warning("artista {} nao possui registros suficientes kfold.".format(artist))
                else:
                    train_x = self.dict_artists[artist][0][:split_train]
                    train_y = self.dict_artists[artist][1][:split_train]

                    folds_x = cp.array_split(train_x, k)
                    folds_y = cp.array_split(train_y, k)

                    self.dict_artists_kfold[artist] = (folds_x, folds_y)

                    folds_fotos += split_train
                    test_fotos += (artist_photos - split_train)

                    test_x = self.dict_artists[artist][0][split_train:]
                    test_y = self.dict_artists[artist][1][split_train:]

                    self.dict_artists_train[artist] = (train_x, train_y)
                    self.dict_artists_kfold[artist] = (folds_x, folds_y)
                    self.dict_artists_test[artist] = (test_x, test_y)


        # por restringir artistas, muda a lista de artistas unicos
        if lost_artist:
            self.unique_artists = list(self.dict_artists_kfold.keys())

        logging.info("add {} artistas / {} fotos ao dict_artists_kfolds.".format(len(self.dict_artists_kfold.keys()), folds_fotos))
        logging.info("add {} artistas / {} fotos ao dict_artists_tests.".format(len(self.dict_artists_test.keys()), test_fotos))

        return self.dict_artists_train, self.dict_artists_kfold, self.dict_artists_test

    def get_dictionary_moc_ecoc_artists(self, ecoc=1, lbp=False):
        # quebra o dataset em treino ,teste e validacao

        if ecoc <= 1:
            logging.info("ini treino MOC")
        else:
            logging.info("ini treino ECOC com %fx o numero de bits.", ecoc)

        if lbp:
            logging.info("Descritor: LBP")
        else:
            logging.info("Descritor: HOG")

        qty_classes = len(self.unique_artists)
        logging.info("gerando matriz de binarios para : %i artistas", qty_classes)

        # gera uma matriz de binários para atribuir às classes
        self.moc_ecoc_qty = math.ceil(math.ceil(math.log2(qty_classes)) * ecoc)

        binary_format = "{0:0" + str(self.moc_ecoc_qty) + "b}"

        # lista_randomica
        max_random_val = 2 ** self.moc_ecoc_qty

        np.random.seed(self.random_state)
        if ecoc > 1:
            randomlist = []
            # evita repeticao de randomicos
            while len(set(randomlist)) < qty_classes:
                randomlist = list(set(randomlist))
                n = np.random.randint(0, max_random_val)
                randomlist.append(n)
        else:
            randomlist = [x for x in range(max_random_val)]

        matriz_binarios = []
        for i in randomlist:
            bin_rep = binary_format.format(i)
            matriz_binarios.append(bin_rep)


        np.random.shuffle(matriz_binarios)

        self.dict_moc_ecoc_artists = {}
        for i in range(qty_classes):
            self.dict_moc_ecoc_artists[self.unique_artists[i]] = matriz_binarios[i]

        logging.info("Matriz de bits para ECOC/MOC {}".format(self.dict_moc_ecoc_artists))


        self.list_datasets_moc_ecoc = []
        for i in range(self.moc_ecoc_qty):
            classes_dataset_0 = []
            classes_dataset_1 = []
            for classe in self.dict_moc_ecoc_artists:
                if self.dict_moc_ecoc_artists[classe][i] == "1":
                    classes_dataset_1.append(classe)
                else:
                    classes_dataset_0.append(classe)
            self.list_datasets_moc_ecoc.append((classes_dataset_0, classes_dataset_1))

        return self.dict_moc_ecoc_artists, self.list_datasets_moc_ecoc

    def get_moc_ecoc_x_y(self, dict_data, lista_classe_0, lista_classe_1, lbp=False):
        for i in range(len(lista_classe_0)):
            if i == 0:
                x_train_0 = dict_data[lista_classe_0[i]][0]
                y_classes_reais_0 = dict_data[lista_classe_0[i]][1]
            else:
                x_train_0 = cp.concatenate([x_train_0, dict_data[lista_classe_0[i]][0]])
                y_classes_reais_0 = cp.concatenate(
                    [y_classes_reais_0, dict_data[lista_classe_0[i]][1]])

        for i in range(len(lista_classe_1)):
            if i==0:
                x_train_1 = dict_data[lista_classe_1[i]][0]
                y_classes_reais_1 = dict_data[lista_classe_1[i]][1]
            else:
                x_train_1 = cp.concatenate([x_train_1, dict_data[lista_classe_1[i]][0]])
                y_classes_reais_1 = cp.concatenate(
                    [y_classes_reais_1, dict_data[lista_classe_1[i]][1]])

        x_train = cp.concatenate([x_train_0, x_train_1])
        y_train_0 = cp.full(x_train_0.shape[0], -1)
        y_train_1 = cp.full(x_train_1.shape[0], 1)
        y_train = cp.concatenate([y_train_0, y_train_1])
        y_classes_reais = cp.concatenate([y_classes_reais_0, y_classes_reais_1])
        y_train = y_train.reshape(-1, 1)
        y_classes_reais = y_classes_reais.reshape(-1, 1)
        return x_train, y_train, y_classes_reais

    def get_moc_ecoc_x_y_fold(self, dict_data, lista_classe_0, lista_classe_1, folds=[], lbp=False):
        j = 0
        k = 0
        for fold in folds:
            for i in range(len(lista_classe_0)):
                if j == 0:
                    x_train_0 = dict_data[lista_classe_0[i]][0][fold]
                    y_classes_reais_0 = dict_data[lista_classe_0[i]][1][fold]
                    j = 1
                else:
                    x_train_0 = cp.concatenate([x_train_0, dict_data[lista_classe_0[i]][0][fold]])
                    y_classes_reais_0 = cp.concatenate(
                        [y_classes_reais_0, dict_data[lista_classe_0[i]][1][fold]])

            for i in range(len(lista_classe_1)):
                if k==0:
                    x_train_1 = dict_data[lista_classe_1[i]][0][fold]
                    y_classes_reais_1 = dict_data[lista_classe_1[i]][1][fold]
                    k = 1
                else:
                    x_train_1 = cp.concatenate([x_train_1, dict_data[lista_classe_1[i]][0][fold]])
                    y_classes_reais_1 = cp.concatenate(
                        [y_classes_reais_1, dict_data[lista_classe_1[i]][1][fold]])

        x_train = cp.concatenate([x_train_0, x_train_1])
        y_train_0 = cp.full(x_train_0.shape[0], -1)
        y_train_1 = cp.full(x_train_1.shape[0], 1)
        y_train = cp.concatenate([y_train_0, y_train_1])
        y_classes_reais = cp.concatenate([y_classes_reais_0, y_classes_reais_1])
        y_train = y_train.reshape(-1, 1)
        y_classes_reais = y_classes_reais.reshape(-1, 1)
        return x_train, y_train, y_classes_reais

    def hamming_distance(self, bit_1, bit_2):
        hamming = 0
        # hamming = abs(np.array(list(bit_1)).astype(np.int8) - np.array(list(bit_2)).astype(np.int8)).sum()
        size = len(bit_1)
        for x in range(size):
            hamming += abs(int(bit_2[x]) - int(bit_1[x]))
        return hamming

    def min_hamming_distance(self, val, list_vals, max_hamming=-1):
        # ini = datetime.datetime.now()
        min_hamming = max_hamming
        if max_hamming < 0:
            min_hamming = len(val) + 1
        for j in list_vals:
            hd = self.hamming_distance(val, j)
            if hd==1:
                return j
            if hd < min_hamming:
                min_hamming = hd
                min_val = j
        # fim = datetime.datetime.now()
        # tempo = fim - ini
        return min_val

    def decoder_resultados_oc(self, dict_moc, resultados, y_classes_reais, tipo=""):
        # cria um dicionário inverso para o
        dict_classes = {}
        for classe in dict_moc.keys():
            dict_classes[dict_moc[classe]] = classe

        res_moc = []
        for res in range(len(resultados[0])):
            lista_res = "".join([res_y[res][0] for res_y in resultados])
            res_moc.append(lista_res)

        res_moc_classes = []

        # para não fazer a contagem item a item no metodo min_hamming_distante
        max_hamming = len(res_moc[0])

        for x in res_moc:
            if x in dict_classes.keys():
                res_moc_classes.append(dict_classes[x])
            else:
                res_moc_classes.append(dict_classes[self.min_hamming_distance(x,
                                                                              dict_classes.keys(),
                                                                              max_hamming=max_hamming)])

        res_moc_classes = cp.array(res_moc_classes).reshape(-1, 1)

        res_moc_classes = res_moc_classes.reshape(-1, 1)
        y_classes_reais = y_classes_reais.reshape(-1, 1)

        logging.info("ecoc: acuracia %s %f", tipo, (res_moc_classes == y_classes_reais).astype(int).mean())
# Out:
# Mounted at /content/drive

# %%
import sys
import logging
import h5py
import cupy as cp
import numpy as np
import math
import random
import datetime
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import logging
import numpy as np
import cupy as cp
import math
from cvxopt import matrix, solvers

class svm_gpu:
    def __init__(self, X, Y, config=None):
        '''
        inicializador da classe
        :param X: caracteristicas para treinar
        :param Y: resultado desejado
        :param log_file: nome do arquivo de log para guardar
        '''
        logging.info("instanciado um svm")
        self.X = X
        self.Y = Y
        self.config = config
        if config:
            self.kkttol = config['kkttol']
            self.chunksize = config['chunksize']
            self.bias = config['bias']
            self.sv = config['sv']
            self.svcoeff = config['svcoeff']
            self.normalw = config['normalw']
            self.C = config['C']
            self.h = config['h']
            self.debug = config['debug']
            self.alphatol = config['alphatol']
            self.SVThresh = config['SVThresh']
            self.qpsize = config['qpsize']
            self.logs = config['logs']
            self.configs = config['configs']
            self.kernelpar = config['kernelpar']
            self.randomWS = config['randomWS']
        else:
            self.kkttol = 5e-2
            self.chunksize = 4000
            self.bias = []
            self.sv = []
            self.svcoeff = []
            self.normalw = []
            self.C = 2
            self.h = 0.01
            self.debug = True
            self.alphatol = 1e-2
            self.SVThresh = 0.
            self.qpsize = 512
            self.logs = []
            self.configs = {}
            self.kernelpar = 1  # ao aumentar eentre 1 e 2, melhorou a acuracia em testes
            self.randomWS = True

    def prep(self):
        '''
        etapa de validacao dos atributos
        :return:
        '''
        self.N, self.ne = self.X.shape
        self.class0 = self.Y == -1
        self.class1 = self.Y == 1

        self.Y = self.Y.reshape(self.N, 1)
        self.qpsize = min(self.N, self.qpsize)
        self.C = cp.full((self.N, 1), self.C)
        self.alpha = cp.zeros((self.N, 1))

        if self.debug:
            logging.debug("Working set possui {} exemplos de classe positiva e {} exemplos de classe negativa.".format(self.Y[self.class1].shape[0], self.Y[self.class0].shape[0]))





    def fit(self):
        '''
        Treina o SVM
        codigo obtido na aula da disciplina SIN5016 originalmente em matlab
        convertido para python e orientacao a objetos.
        :return:
        '''
        logging.info("svm.fit")

        X = self.X
        Y = self.Y
        logging.info('X.shape %s', str(X.shape))
        logging.info('Y.shape %s', str(Y.shape))
        logging.info('config: {}'.format(self.config))

        saida_svm = cp.zeros((self.N,1))
        alphaOld = cp.copy(self.alpha)
        if self.Y[self.class1].shape[0] == self.N:
            self.bias = 1
            return

        if self.Y[self.class0].shape[0] == self.N:
            self.bias = -1
            return

        iteracao = 0
        workset = cp.full((self.N,1), False)
        sameWS = 0
        self.bias = 0
        while True:
            # logging.info('Iteracao %i', iteracao)

            # Passo 1: determina os vetores de suporte
            self.findSV()

            # Passo 2: Encontra a saída para o SVM
            if iteracao == 0:
                changedSV = self.svind # todo: cp.copy(self.svind)
                changedAlpha = self.alpha[changedSV] # todo: cp.copy(self.alpha[changedSV])
                saida_svm = cp.zeros((self.N, 1))
            else:
                changedSV = cp.flatnonzero(alphaOld != self.alpha)
                changedAlpha = self.alpha[changedSV] - alphaOld[changedSV]

            # Função de kernel RBF
            chunks1 = math.ceil(self.N / self.chunksize)
            chunks2 = math.ceil(len(changedSV) / self.chunksize)

            for ch1 in range(chunks1):
                ini_ind1 = (ch1)*self.chunksize
                fim_ind1 = min(self.N, (ch1+1)*self.chunksize)
                for ch2 in range(chunks2):
                    ini_ind2 = (ch2)*self.chunksize
                    fim_ind2 = min(len(changedSV), (ch2+1)*self.chunksize)
                    K12 = self.calc_rbf(X[ini_ind1:fim_ind1, :], X[changedSV][ini_ind2:fim_ind2])
                    coeff = changedAlpha[ini_ind2:fim_ind2]*Y[changedSV[ini_ind2:fim_ind2]]
                    saida_svm[ini_ind1:fim_ind1] = saida_svm[ini_ind1:fim_ind1] + cp.dot(K12, coeff)

            # Passo 3: Calcule o bias da função de decisão
            workSV = cp.flatnonzero(cp.logical_and(self.SVnonBound, workset))
            if not workSV.size == 0:
                self.bias = cp.mean(Y[workSV] - saida_svm[workSV])


            # Passo 4: Calcula as condicoes de KKT
            KKT = (saida_svm+self.bias)*self.Y-1
            KKTViolations1 = cp.logical_and(self.SVnonBound, (abs(KKT)>self.kkttol))
            KKTViolations2 = cp.logical_and(self.SVBound, KKT > self.kkttol)
            KKTViolations3 = cp.logical_and(cp.logical_not(self.SV), (KKT < (self.kkttol*-1)))
            KKTViolations = cp.logical_or(KKTViolations1, KKTViolations2)
            KKTViolations = cp.logical_or(KKTViolations, KKTViolations3)

            # (uint8((SVnonbound & (abs(KKT) > svm.kkttol)) | ...
            # (SVbound & (KKT > svm.kkttol)) | ...
            #        (~SV & (KKT < -svm.kkttol))))



            count_kkt = len(cp.flatnonzero(KKTViolations))

            if iteracao % 100 == 0:
                logging.info('iteracao: {} KKT violacoes: {}'.format(iteracao, count_kkt))

            if count_kkt == 0:
                # sem violacoes, terminar
                logging.info('fim do treino por fim das violacoes de KKT, total iteracoes: {}'.format(iteracao))
                break

            # Passo 5: determinar o novo conjunto de trabalho
            searchDir = saida_svm - self.Y
            set1 = cp.logical_and(cp.logical_or(self.SV, self.class0), cp.logical_or(cp.logical_not(self.SVBound), self.class1))
            set2 = cp.logical_and(cp.logical_or(self.SV, self.class1), cp.logical_or(cp.logical_not(self.SVBound), self.class0))

            if self.randomWS:
                cp.random.seed(0)
                searchDir = cp.random.rand(self.N, 1)
                set1 = self.class1
                set2 = self.class0
                self.randomWS = False


            # Passo 6: Seleciona o working set
            #          (QPsize/2 exemplos de set1, QPsize/2 de set2
            worksetOld = cp.copy(workset)
            workset = cp.full((self.N, 1), False)

            if cp.flatnonzero(cp.logical_or(set1, set2)).size <= self.qpsize:
                workset[cp.logical_or(set1, set2)] = True
            elif cp.flatnonzero(set1).size <= math.floor(self.qpsize/2):
                workset[set1] = True
                set2 = cp.flatnonzero(cp.logical_and(set2, cp.logical_not(workset)))
                ind = searchDir[set2].argsort(0)
                from2 = min(set2.size, self.qpsize - cp.flatnonzero(workset).size)
                workset[set2[ind[:from2]]] = True
            elif cp.flatnonzero(set2).size <= math.floor(self.qpsize/2):
                workset[set2] = True
                set1 = cp.flatnonzero(cp.logical_and(set1, cp.logical_not(workset)))
                ind = -searchDir[set1].argsort(0)
                from1 = min(set1.size, self.qpsize - cp.flatnonzero(workset).size)
                workset[set1[ind[:from1]]] = True
            else:
                set1 = cp.flatnonzero(set1)
                ind = (-searchDir[set1]).argsort(0)
                from1 = min(set1.size, math.floor(self.qpsize /2))
                workset[set1[ind[:from1]]] = True

                set2 = cp.flatnonzero(cp.logical_and(set2, cp.logical_not(workset)))
                ind = searchDir[set2].argsort(0)
                from2 = min(set2.size, self.qpsize - cp.flatnonzero(workset).size)
                workset[set2[ind[:from2]]] = True

            worksetind = cp.flatnonzero(workset)

            if cp.all(workset==worksetOld):
                sameWS +=1
                if sameWS == 3:
                    logging.info('fim do treino por por permanecer no mesmo workingset por: %i iteracoes', sameWS)
                    break
            else:
                sameWS = 0

            worksize = worksetind.size
            nonworkset = cp.logical_not(workset)

            # Passo 7: Determine a parte da programação linear
            nonworkSV = cp.flatnonzero(cp.logical_and(nonworkset, self.SV))
            qBN = 0
            if nonworkSV.size > 0:
                chunks = math.ceil(nonworkSV.size/self.chunksize)
                for ch in range(chunks):
                    ind_ini = self.chunksize*ch
                    ind_fim = min(nonworkSV.size, self.chunksize*(ch+1))
                    Ki = self.calc_rbf(X[worksetind, :], X[nonworkSV[ind_ini:ind_fim], :])
                    qBN += Ki.dot(self.alpha[nonworkSV[ind_ini:ind_fim]] * Y[nonworkSV[ind_ini:ind_fim]])
                qBN = qBN * Y[workset].reshape(-1,1)

            f = qBN - cp.ones((worksize,1))

            # Passo 8: Soluciona a programação quadrática
            eps_2_3 = np.spacing(1)**(2/3)
            H = self.calc_rbf(self.X[worksetind, :], self.X[worksetind, :])
            H += cp.diag(cp.ones((worksize, 1))*eps_2_3)
            H = H * (self.Y[workset].dot(Y[workset].T))

            A = Y[workset].T.astype('float').reshape(1,-1)

            if nonworkSV.size > 0:
                eqconstr = -self.alpha[nonworkSV].T.dot(Y[nonworkSV])
            else:
                eqconstr = cp.zeros(1)

            VLB = cp.zeros((1, worksize))
            VUB = self.C[workset].astype('float')


            start_val = self.alpha[workset]
            start_val = start_val.reshape(worksize, 1)

            # cvxopt = quadprog(C1, C2, C3, C4, C5, C6      , C7 , C8 ,
            # matlab = quadprog(H , f , [], [], A , eqconstr, VLB, VUB, startVal,

            # _H = matrix(H) #P #todo: ver direito isso ae
            _f = matrix(np.array(f.get())) #q

            tmp1 = cp.diag(cp.ones(worksize) * -1)
            tmp2 = cp.identity(worksize)
            G = matrix(np.array(cp.vstack((tmp1, tmp2)).get()))

            tmp1 = cp.zeros(worksize)
            tmp2 = cp.ones(worksize) * 10.
            h = matrix(np.array(cp.hstack((tmp1, tmp2)).get()))

            _c3 = matrix(np.array(cp.vstack((cp.eye(worksize)*-1,cp.eye(worksize))).get())) #G
            _c4 = matrix(np.array(cp.hstack((cp.zeros(worksize), cp.ones(worksize) * 10)).get())) #h
            _A = matrix(np.array(A.get())) #A
            _eqconstr = matrix(np.array(eqconstr.get())) #b
            # _VLB = matrix(VLB)
            # _VUB = matrix(VUB)
            _start_val = matrix(np.array(start_val.get()))

            H = self.calc_rbf(X[worksetind], X[worksetind])
            eps_2_3 = np.spacing(1) ** (2 / 3)
            H = H + cp.diag(cp.full((worksize, worksize), eps_2_3).diagonal())
            H = H * cp.dot(Y[workset].reshape(-1,1), (Y[workset].T.reshape(1,-1)))
            _H = matrix(np.array(H.get()).astype(float))
            solvers.options['maxiters'] = 1000
            solvers.options['show_progress'] = self.debug
            # solvers.options['abstol'] = 1e-8
            # solvers.options['reltol'] = 1e-8
            # solvers.options['feastol'] = 1e-8
            # solvers.options['refinement'] = 1
            sol = solvers.qp(_H, _f, G, h, A=_A, b=_eqconstr, initvals=_start_val)
            workAlpha = cp.array(sol['x'])

            # logging.info('work alpha: %s', str(workAlpha))

            alphaOld = cp.copy(self.alpha)
            self.alpha[workset] = workAlpha.squeeze()
            iteracao += 1

        self.svcoeff = self.alpha[self.svind] * Y[self.svind]
        self.SV = X[self.svind, :]

    def findSV(self):
        '''
        busca os vetores de suporte baseado nos criterios de alphatol / threshold
        :return:
        '''
        maxalpha = self.alpha.max()
        if maxalpha > self.alphatol:
            self.SVThresh = self.alphatol
        else:
            eps_1 = np.spacing(1)
            self.SVThresh = math.exp((math.log(max(eps_1, maxalpha))+ math.log(eps_1))/2)

        self.SV = self.alpha>=self.SVThresh

        self.SVBound = self.alpha>=(self.C-self.alphatol)

        self.SVnonBound = cp.logical_and(self.SV, cp.logical_not(self.SVBound))
        self.svind = cp.flatnonzero(self.SV)

    def calc_rbf(self, X1, X2):
        '''
        funcao kernel rbf
        :param X1:
        :param X2:
        :return:
        '''
        N1, d = X1.shape
        N2, d = X2.shape

        dist2 = cp.tile(cp.sum((X1 ** 2).T, 0), (N2, 1)).T
        dist2 += cp.tile(cp.sum((X2 ** 2).T, 0), (N1, 1))
        dist2 -= 2 * X1.dot(X2.T)
        return cp.exp(-dist2/(2*self.kernelpar**2))

    def return_instance_for_predict(self):
        '''
        Retorna uma instancia do modelo treinado com apenas o necessario
        :return:
        '''
        #
        self.X = None
        self.Y = None
        self.alphatol = None
        self.kkttol = None
        self.alpha = None
        self.svind = None
        self.class1 = None
        self.class0 = None
        self.C = None
        self.normalw = None
        self.ne = None
        self.SVBound = None
        self.SVnonBound = None
        self.SV = self.SV.astype(cp.float16)
        self.svcoeff = self.svcoeff.astype(cp.float16)
        return self

    def predict(self, X):
        N, d = X.shape
        nbSV = self.SV.shape[0]
        chsize = self.chunksize
        Y1 = cp.zeros((N, 1))
        chunks1 = math.ceil(N / chsize)
        chunks2 = math.ceil(nbSV / chsize)

        for ch1 in range(chunks1):
            ini_ind1 = (ch1) * self.chunksize
            fim_ind1 = min(self.N, (ch1 + 1) * self.chunksize)
            for ch2 in range(chunks2):
                ini_ind2 = (ch2) * self.chunksize
                fim_ind2 = min(nbSV, (ch2 + 1) * self.chunksize)
                K12 = self.calc_rbf(X[ini_ind1:fim_ind1, :], self.SV[ini_ind2:fim_ind2, :])
                Y1[ini_ind1:fim_ind1] += K12.dot(self.svcoeff[ini_ind2:fim_ind2])

        Y1 += self.bias
        Y = cp.sign(Y1)
        Y[Y==0] = 1
        return Y, Y1


def acuracia(y, y_predito):
    '''
    calcula a acuracia
    :param y: y desejado
    :param y_predito: y predito
    :return: acuraria de 0 a 1
    '''
    y.reshape(y_predito.shape)
    acuracia = (y==y_predito).astype(float).mean()
    return acuracia

# %%
import sys
import logging
import numpy as np
import cupy as cp
import datetime
import pickle


def treino_svm(train, test, config, valida_teste=True):
    ini_treino = datetime.datetime.now()
    x_train, y_train_svm, y_train_class = train


    svm_ = svm_gpu(x_train, y_train_svm, config=config)
    svm_.debug = False
    svm_.prep()
    svm_.fit()

    y_predict_train, y1_predict_train = svm_.predict(x_train)
    acuracia_treino = acuracia(y_train_svm, y_predict_train)

    logging.info("Treino Acuracia:{}".format(acuracia_treino))

    if valida_teste:
        x_test, y_test_svm, y_test_class = test
        y_predict_test, y1_predict_test = svm_.predict(x_test)
        acuracia_test = acuracia(y_test_svm, y_predict_test)
        logging.info("Teste Acuracia:{}".format(acuracia_test))

    fim_treino = datetime.datetime.now()

    logging.info("tempo treinamento {}".format(fim_treino - ini_treino))
    if valida_teste:
        return svm_.return_instance_for_predict(), acuracia_treino, acuracia_test
    else:
        return svm_.return_instance_for_predict(), acuracia_treino

def treino_svm_total(dt_obj, config):
    logging.info("ini treino_svm_total")
    ini_full = datetime.datetime.now()

    moc_svms_full = []
    for svm_dataset in dt_obj.list_datasets_moc_ecoc:
        x_train, y_train_svm, y_train_class = dt_obj.get_moc_ecoc_x_y(dt_obj.dict_artists_train, svm_dataset[0], svm_dataset[1])
        x_test, y_test_svm, y_test_class = dt_obj.get_moc_ecoc_x_y(dt_obj.dict_artists_test, svm_dataset[0], svm_dataset[1])

        svm_pesos, a, b = treino_svm((x_train, y_train_svm, y_train_class), (x_test, y_test_svm, y_test_class), config=config)
        moc_svms_full.append(svm_pesos)

    pickle.dump(moc_svms_full, open("5016_svm_hog_moc_gpu_{}.dat".format(len(dt_obj.unique_artists)), "wb"))

    resultados = []
    for svm_treinado in moc_svms_full:
        Ysvm_train, Y1svm_train = svm_treinado.predict(x_train)
        Ysvm_train[Ysvm_train < 0] = '0'
        Ysvm_train[Ysvm_train > 0] = '1'
        resultados.append(np.array(Ysvm_train.get()).astype(int).astype(str))

    dt_obj.decoder_resultados_oc(dt_obj.dict_moc_ecoc_artists, resultados, y_train_class, "treino")

    resultados_teste = []
    for svm_treinado in moc_svms_full:
        Ysvm_train, Y1svm_train = svm_treinado.predict(x_test)
        Ysvm_train[Ysvm_train < 0] = '0'
        Ysvm_train[Ysvm_train > 0] = '1'
        resultados_teste.append(np.array(Ysvm_train.get()).astype(int).astype(str))

    dt_obj.decoder_resultados_oc(dt_obj.dict_moc_ecoc_artists, resultados_teste, y_test_class, "teste")

    fim_full = datetime.datetime.now()
    pickle.dump(moc_svms_full, open("/content/drive/MyDrive/5016_svm_hog_moc_gpu_ecoc_4_{}.dat".format(len(dt_obj.unique_artists)), "wb"))
    pickle.dump(dt_obj.dict_moc_ecoc_artists, open("/content/drive/MyDrive/dict_moc_ecoc_artists_ecoc_4_{}.dat".format(len(dt_obj.unique_artists)), "wb"))

    logging.info("tempo treino_svm_total: {}".format(fim_full-ini_full))
    logging.info("fim treino_svm_total")

def kfold_cross_validation(dt_obj, config):
    logging.info("ini kfold_cross_validation")
    ini_ = datetime.datetime.now()

    moc_svms_full = []
    k = dt_obj.kfolds
    list_acuracia_kfolds = []
    bit = 0
    for svm_dataset in dt_obj.list_datasets_moc_ecoc:
        # cada iteracao corresponde a um bit do moc/ecoc
        list_folds = np.arange(k)
        result_test = []
        result_train = []
        
        for fold in range(k):
            folds_train = np.delete(list_folds, fold)
            folds_test = np.delete(list_folds, folds_train)

            x_train, y_train_svm, y_train_class = dt_obj.get_moc_ecoc_x_y_fold(dt_obj.dict_artists_kfold,
                                                                               svm_dataset[0],
                                                                               svm_dataset[1],
                                                                               folds_train)

            x_test, y_test_svm, y_test_class = dt_obj.get_moc_ecoc_x_y_fold(dt_obj.dict_artists_kfold,
                                                                       svm_dataset[0],
                                                                       svm_dataset[1],
                                                                       folds_test)

            svm_pesos, acuracia_treino, acuracia_test = treino_svm((x_train, y_train_svm, y_train_class),
                                                                   (x_test, y_test_svm, y_test_class), config=config)
            result_train.append(acuracia_treino)
            result_test.append(acuracia_test)

        bit += 1
        list_acuracia_kfolds.append(float(cp.array(result_test).mean()))
        logging.info("acuracia media kfold treino: {} ".format(cp.array(result_train).mean()))
        logging.info("acuracia media kfold teste: {} ".format(cp.array(result_test).mean()))

    fim_ = datetime.datetime.now()
    logging.info("tempo kfold_cross_validation: {}".format(fim_-ini_))
    logging.info("fim kfold_cross_validation")
    logging.info("kfolds lista acuracia: {}".format(list_acuracia_kfolds))



# kfold_cross_validation(dt_hog)


print()

# %%
import logging
logging.basicConfig(filename="/content/drive/MyDrive/svm_workflow_hog_ecoc4.py.log", 
                    format='%(asctime)s %(message)s', 
                    level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
dt_hog = dataprep(hdf5_path="/content/drive/Shareddrives/grupo_estudos/hdf5/hog_11_15_20_56",
                             max_artists=2544)

dt_hog.load_hdf5()
dt_hog.get_dictionary_artists()
dt_hog.get_dictionary_kfold_test()
dt_hog.get_dictionary_moc_ecoc_artists(ecoc=4)
config = {}
config['kkttol'] = 5e-2
config['chunksize'] = 8000
config['bias'] = []
config['sv'] = []
config['svcoeff'] = []
config['normalw'] = []
config['C'] = 2
config['h'] = 0
config['debug'] = True
config['alphatol'] = 1e-2
config['SVThresh'] = 0
config['qpsize'] = 256
config['logs'] = []
config['configs'] = {}
config['kernelpar'] = 1.6
config['randomWS'] = True
treino_svm_total(dt_hog, config)
# kfold_cross_validation(dt_hog)
# Out:
# add 2544 artistas / 42634 fotos ao dict_artists_kfolds.
# add 2544 artistas / 11660 fotos ao dict_artists_tests.
# ini treino ECOC com 4.000000x o numero de bits.
# Descritor: HOG
# gerando matriz de binarios para : 2544 artistas
# Matriz de bits para ECOC/MOC {2890.0: '001010001011110110011111011000100100111101100111', 2364.0: '101101100000001101001110101011111110000011111011', 7463.0: '010100101101001111111101111100101010111000000100', 8717.0: '001001010110110001010010101111111000010010010110', 5323.0: '010111101001110000101111100000101100111100010111', 2759.0: '101111100000111010100000101101011110110001010010', 2221.0: '010010001110001110010101110011011000111001100000', 5865.0: '001101111001110111110000101011100111101000011011', 256.0: '100111101001110011010101101110110110001000101011', 3491.0: '101110011000000001111100111101100110111100100100', 5193.0: '000101100111111111101100010011011101011011001100', 7232.0: '010001110000101011111111110100110011101110111111', 1789.0: '101001010010000010100001110010101110100100100111', 9695.0: '110001111110011010000010011100011101001100110001', 9159.0: '111100000100001111101101001000110000001011110100', 1320.0: '100001000110110011100100111111110101010111011110', 4320.0: '011010111010010000111010101011111010101001010000', 9448.0: '100011011110010000011100001011001101100011100111', 5654.0: '010011111110001100101100101010000100100011101110', 3494.0: '110010000111111000111110100101111001011111110001', 2114.0: '101011110011010111100111110111101110111011011101', 8545.0: '000000100001111101011101111110101101011011000111', 2580.0: '100101010010110111100110011110000011101011010001', 5429.0: '010011011101011101011101011111011000111001110010', 3228.0: '110101100000001110001010100001101111000101100101', 6053.0: '111100110100110010010110100101001010010100101111', 4401.0: '001010010101110000111010011100100011000110001100', 2747.0: '101101110001101011011111111011101101001011111010', 7675.0: '001001011010101001110001001001110001110011101100', 9449.0: '101010110010000111111010110001011010111110110001', 1040.0: '111001001101100010011010010000000110000000101010', 4245.0: '101011100100110010001101111101100101110101110110', 2141.0: '100000001011001011011101100101010011101001011100', 7995.0: '100101111000111011000101001011110100000100110100', 2739.0: '100110010101101010001000110111011010000011001101', 4773.0: '011010001101100100000010001000000100110111101010', 4447.0: '110001011001100101101001110100111010100101000111', 5918.0: '011111010111010110111101101000000111000000011001', 245.0: '101011001001111110000101110100110111100011011000', 6172.0: '111110011010010001101111111000111100101100101000', 9669.0: '101100110010111101001000100001111110011011011100', 6781.0: '011101110101010110010000000000010001101001000010', 7512.0: '010001011111000000000001011110010010010101001110', 9231.0: '000110001110110101000011110011010101100001100000', 854.0: '001011100000101001100100000001011101111010010000', 7959.0: '111010001100111101110001101010011101101100000010', 1873.0: '010111111101111000011110110011010000001101001111', 6737.0: '100111011000000101011000100011110111000011111001', 6398.0: '011100010011000011011110100100000110010101011101', 1992.0: '110111011111111010111100100010111000011100010000', 5135.0: '010110100010010010011111100011101100011010001111', 7122.0: '100101110101001101010100101100101010000000010111', 8638.0: '011110110001110111101111000100001010011110011100', 5460.0: '111001000000001110010101100101111110011100111011', 305.0: '001110110111000000110101100001110010101000000001', 5683.0: '101101100100011111101111010111101000000001100000', 8826.0: '000110010101010000111011000010110000000101000101', 9451.0: '001100100011000101001010000101010100011111100001', 8476.0: '000100011110100100111110011100110011000010001011', 2219.0: '111111111100111001111110001101000010101101101011', 2365.0: '011001100101011000001100000111001100100110000110', 897.0: '000100111011111100110110100010011001000001011010', 733.0: '111110111000111100101100111111110011111101000111', 6642.0: '011100001110000001110100100001011111000000101000', 7847.0: '001000010001111101110111001000001111000000001011', 6088.0: '010101010011011111010011100101101010011111110010', 2368.0: '0010010 ...
# ini treino_svm_total
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42166
# iteracao: 200 KKT violacoes: 41987
# iteracao: 300 KKT violacoes: 41959
# iteracao: 400 KKT violacoes: 41007
# iteracao: 500 KKT violacoes: 41536
# iteracao: 600 KKT violacoes: 39537
# iteracao: 700 KKT violacoes: 40731
# iteracao: 800 KKT violacoes: 40876
# iteracao: 900 KKT violacoes: 39780
# iteracao: 1000 KKT violacoes: 39403
# iteracao: 1100 KKT violacoes: 38224
# iteracao: 1200 KKT violacoes: 38175
# iteracao: 1300 KKT violacoes: 37942
# iteracao: 1400 KKT violacoes: 36036
# iteracao: 1500 KKT violacoes: 34723
# iteracao: 1600 KKT violacoes: 35063
# iteracao: 1700 KKT violacoes: 31656
# iteracao: 1800 KKT violacoes: 28421
# iteracao: 1900 KKT violacoes: 23780
# iteracao: 2000 KKT violacoes: 22029
# iteracao: 2100 KKT violacoes: 20025
# iteracao: 2200 KKT violacoes: 16154
# iteracao: 2300 KKT violacoes: 12644
# iteracao: 2400 KKT violacoes: 8490
# iteracao: 2500 KKT violacoes: 1135
# iteracao: 2600 KKT violacoes: 438
# fim do treino por fim das violacoes de KKT, total iteracoes: 2683
# Treino Acuracia:0.9998358117934043
# Teste Acuracia:0.583876500857633
# tempo treinamento 0:03:38.924245
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42161
# iteracao: 200 KKT violacoes: 42100
# iteracao: 300 KKT violacoes: 41802
# iteracao: 400 KKT violacoes: 41241
# iteracao: 500 KKT violacoes: 41439
# iteracao: 600 KKT violacoes: 41386
# iteracao: 700 KKT violacoes: 40312
# iteracao: 800 KKT violacoes: 37981
# iteracao: 900 KKT violacoes: 39894
# iteracao: 1000 KKT violacoes: 38591
# iteracao: 1100 KKT violacoes: 39054
# iteracao: 1200 KKT violacoes: 38302
# iteracao: 1300 KKT violacoes: 37777
# iteracao: 1400 KKT violacoes: 32218
# iteracao: 1500 KKT violacoes: 36133
# iteracao: 1600 KKT violacoes: 31104
# iteracao: 1700 KKT violacoes: 31571
# iteracao: 1800 KKT violacoes: 32285
# iteracao: 1900 KKT violacoes: 25843
# iteracao: 2000 KKT violacoes: 23605
# iteracao: 2100 KKT violacoes: 21878
# iteracao: 2200 KKT violacoes: 17408
# iteracao: 2300 KKT violacoes: 12262
# iteracao: 2400 KKT violacoes: 6459
# iteracao: 2500 KKT violacoes: 4987
# iteracao: 2600 KKT violacoes: 2345
# iteracao: 2700 KKT violacoes: 19
# fim do treino por fim das violacoes de KKT, total iteracoes: 2739
# Treino Acuracia:0.9995543462963832
# Teste Acuracia:0.5818181818181818
# tempo treinamento 0:03:39.883581
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42165
# iteracao: 200 KKT violacoes: 42099
# iteracao: 300 KKT violacoes: 41551
# iteracao: 400 KKT violacoes: 41695
# iteracao: 500 KKT violacoes: 41697
# iteracao: 600 KKT violacoes: 41166
# iteracao: 700 KKT violacoes: 40236
# iteracao: 800 KKT violacoes: 39010
# iteracao: 900 KKT violacoes: 40012
# iteracao: 1000 KKT violacoes: 39822
# iteracao: 1100 KKT violacoes: 38340
# iteracao: 1200 KKT violacoes: 36321
# iteracao: 1300 KKT violacoes: 37504
# iteracao: 1400 KKT violacoes: 37029
# iteracao: 1500 KKT violacoes: 36044
# iteracao: 1600 KKT violacoes: 31518
# iteracao: 1700 KKT violacoes: 33284
# iteracao: 1800 KKT violacoes: 32038
# iteracao: 1900 KKT violacoes: 27355
# iteracao: 2000 KKT violacoes: 23863
# iteracao: 2100 KKT violacoes: 23731
# iteracao: 2200 KKT violacoes: 15881
# iteracao: 2300 KKT violacoes: 13230
# iteracao: 2400 KKT violacoes: 7167
# iteracao: 2500 KKT violacoes: 1408
# iteracao: 2600 KKT violacoes: 2418
# iteracao: 2700 KKT violacoes: 85
# fim do treino por fim das violacoes de KKT, total iteracoes: 2726
# Treino Acuracia:0.9996950790448937
# Teste Acuracia:0.5888507718696397
# tempo treinamento 0:03:40.254404
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42086
# iteracao: 200 KKT violacoes: 41743
# iteracao: 300 KKT violacoes: 41438
# iteracao: 400 KKT violacoes: 41081
# iteracao: 500 KKT violacoes: 40716
# iteracao: 600 KKT violacoes: 39854
# iteracao: 700 KKT violacoes: 40131
# iteracao: 800 KKT violacoes: 39605
# iteracao: 900 KKT violacoes: 38826
# iteracao: 1000 KKT violacoes: 39903
# iteracao: 1100 KKT violacoes: 38520
# iteracao: 1200 KKT violacoes: 37432
# iteracao: 1300 KKT violacoes: 37914
# iteracao: 1400 KKT violacoes: 37100
# iteracao: 1500 KKT violacoes: 32268
# iteracao: 1600 KKT violacoes: 33728
# iteracao: 1700 KKT violacoes: 30483
# iteracao: 1800 KKT violacoes: 27331
# iteracao: 1900 KKT violacoes: 28655
# iteracao: 2000 KKT violacoes: 25361
# iteracao: 2100 KKT violacoes: 18665
# iteracao: 2200 KKT violacoes: 16713
# iteracao: 2300 KKT violacoes: 11768
# iteracao: 2400 KKT violacoes: 9242
# iteracao: 2500 KKT violacoes: 2633
# iteracao: 2600 KKT violacoes: 198
# fim do treino por fim das violacoes de KKT, total iteracoes: 2609
# Treino Acuracia:0.9996716235868086
# Teste Acuracia:0.5841337907375643
# tempo treinamento 0:03:30.257266
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42143
# iteracao: 200 KKT violacoes: 41498
# iteracao: 300 KKT violacoes: 40383
# iteracao: 400 KKT violacoes: 40473
# iteracao: 500 KKT violacoes: 41626
# iteracao: 600 KKT violacoes: 40117
# iteracao: 700 KKT violacoes: 40878
# iteracao: 800 KKT violacoes: 40457
# iteracao: 900 KKT violacoes: 39157
# iteracao: 1000 KKT violacoes: 39936
# iteracao: 1100 KKT violacoes: 39296
# iteracao: 1200 KKT violacoes: 37083
# iteracao: 1300 KKT violacoes: 36914
# iteracao: 1400 KKT violacoes: 37061
# iteracao: 1500 KKT violacoes: 35527
# iteracao: 1600 KKT violacoes: 30866
# iteracao: 1700 KKT violacoes: 29800
# iteracao: 1800 KKT violacoes: 30039
# iteracao: 1900 KKT violacoes: 29130
# iteracao: 2000 KKT violacoes: 22179
# iteracao: 2100 KKT violacoes: 18241
# iteracao: 2200 KKT violacoes: 17624
# iteracao: 2300 KKT violacoes: 11479
# iteracao: 2400 KKT violacoes: 9442
# iteracao: 2500 KKT violacoes: 6180
# iteracao: 2600 KKT violacoes: 69
# fim do treino por fim das violacoes de KKT, total iteracoes: 2672
# Treino Acuracia:0.9996950790448937
# Teste Acuracia:0.5968267581475128
# tempo treinamento 0:03:34.659287
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42081
# iteracao: 200 KKT violacoes: 42009
# iteracao: 300 KKT violacoes: 41952
# iteracao: 400 KKT violacoes: 41743
# iteracao: 500 KKT violacoes: 41556
# iteracao: 600 KKT violacoes: 41213
# iteracao: 700 KKT violacoes: 39879
# iteracao: 800 KKT violacoes: 39655
# iteracao: 900 KKT violacoes: 38733
# iteracao: 1000 KKT violacoes: 39802
# iteracao: 1100 KKT violacoes: 39529
# iteracao: 1200 KKT violacoes: 38220
# iteracao: 1300 KKT violacoes: 37125
# iteracao: 1400 KKT violacoes: 35004
# iteracao: 1500 KKT violacoes: 31806
# iteracao: 1600 KKT violacoes: 33597
# iteracao: 1700 KKT violacoes: 32260
# iteracao: 1800 KKT violacoes: 28913
# iteracao: 1900 KKT violacoes: 28697
# iteracao: 2000 KKT violacoes: 25183
# iteracao: 2100 KKT violacoes: 20193
# iteracao: 2200 KKT violacoes: 15071
# iteracao: 2300 KKT violacoes: 9780
# iteracao: 2400 KKT violacoes: 8578
# iteracao: 2500 KKT violacoes: 3173
# fim do treino por fim das violacoes de KKT, total iteracoes: 2599
# Treino Acuracia:0.9996012572125533
# Teste Acuracia:0.5984562607204117
# tempo treinamento 0:03:26.995909
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42187
# iteracao: 200 KKT violacoes: 42107
# iteracao: 300 KKT violacoes: 41890
# iteracao: 400 KKT violacoes: 40528
# iteracao: 500 KKT violacoes: 40656
# iteracao: 600 KKT violacoes: 41353
# iteracao: 700 KKT violacoes: 40585
# iteracao: 800 KKT violacoes: 40896
# iteracao: 900 KKT violacoes: 40614
# iteracao: 1000 KKT violacoes: 38155
# iteracao: 1100 KKT violacoes: 38339
# iteracao: 1200 KKT violacoes: 37971
# iteracao: 1300 KKT violacoes: 37879
# iteracao: 1400 KKT violacoes: 33710
# iteracao: 1500 KKT violacoes: 33437
# iteracao: 1600 KKT violacoes: 35534
# iteracao: 1700 KKT violacoes: 34504
# iteracao: 1800 KKT violacoes: 30558
# iteracao: 1900 KKT violacoes: 29444
# iteracao: 2000 KKT violacoes: 24852
# iteracao: 2100 KKT violacoes: 22508
# iteracao: 2200 KKT violacoes: 16898
# iteracao: 2300 KKT violacoes: 12910
# iteracao: 2400 KKT violacoes: 7216
# iteracao: 2500 KKT violacoes: 5407
# iteracao: 2600 KKT violacoes: 602
# fim do treino por fim das violacoes de KKT, total iteracoes: 2659
# Treino Acuracia:0.9997185345029789
# Teste Acuracia:0.5900514579759862
# tempo treinamento 0:03:32.803070
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42154
# iteracao: 200 KKT violacoes: 42099
# iteracao: 300 KKT violacoes: 41256
# iteracao: 400 KKT violacoes: 40717
# iteracao: 500 KKT violacoes: 40137
# iteracao: 600 KKT violacoes: 41377
# iteracao: 700 KKT violacoes: 41024
# iteracao: 800 KKT violacoes: 40456
# iteracao: 900 KKT violacoes: 37557
# iteracao: 1000 KKT violacoes: 38494
# iteracao: 1100 KKT violacoes: 36870
# iteracao: 1200 KKT violacoes: 37446
# iteracao: 1300 KKT violacoes: 36037
# iteracao: 1400 KKT violacoes: 34786
# iteracao: 1500 KKT violacoes: 34396
# iteracao: 1600 KKT violacoes: 35113
# iteracao: 1700 KKT violacoes: 29528
# iteracao: 1800 KKT violacoes: 30583
# iteracao: 1900 KKT violacoes: 26076
# iteracao: 2000 KKT violacoes: 24409
# iteracao: 2100 KKT violacoes: 21007
# iteracao: 2200 KKT violacoes: 14630
# iteracao: 2300 KKT violacoes: 10874
# iteracao: 2400 KKT violacoes: 5085
# iteracao: 2500 KKT violacoes: 1424
# fim do treino por fim das violacoes de KKT, total iteracoes: 2581
# Treino Acuracia:0.999530890838298
# Teste Acuracia:0.5879073756432247
# tempo treinamento 0:03:28.352418
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42175
# iteracao: 200 KKT violacoes: 42098
# iteracao: 300 KKT violacoes: 41941
# iteracao: 400 KKT violacoes: 41736
# iteracao: 500 KKT violacoes: 40064
# iteracao: 600 KKT violacoes: 41129
# iteracao: 700 KKT violacoes: 40147
# iteracao: 800 KKT violacoes: 40348
# iteracao: 900 KKT violacoes: 39528
# iteracao: 1000 KKT violacoes: 39316
# iteracao: 1100 KKT violacoes: 39394
# iteracao: 1200 KKT violacoes: 37913
# iteracao: 1300 KKT violacoes: 37734
# iteracao: 1400 KKT violacoes: 37747
# iteracao: 1500 KKT violacoes: 35380
# iteracao: 1600 KKT violacoes: 30979
# iteracao: 1700 KKT violacoes: 32157
# iteracao: 1800 KKT violacoes: 32041
# iteracao: 1900 KKT violacoes: 23415
# iteracao: 2000 KKT violacoes: 20912
# iteracao: 2100 KKT violacoes: 19478
# iteracao: 2200 KKT violacoes: 16466
# iteracao: 2300 KKT violacoes: 12554
# iteracao: 2400 KKT violacoes: 6674
# iteracao: 2500 KKT violacoes: 2561
# iteracao: 2600 KKT violacoes: 39
# fim do treino por fim das violacoes de KKT, total iteracoes: 2696
# Treino Acuracia:0.9997419899610639
# Teste Acuracia:0.5860205831903945
# tempo treinamento 0:03:35.052971
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42202
# iteracao: 200 KKT violacoes: 41738
# iteracao: 300 KKT violacoes: 40327
# iteracao: 400 KKT violacoes: 39741
# iteracao: 500 KKT violacoes: 40389
# iteracao: 600 KKT violacoes: 41305
# iteracao: 700 KKT violacoes: 40403
# iteracao: 800 KKT violacoes: 38549
# iteracao: 900 KKT violacoes: 38983
# iteracao: 1000 KKT violacoes: 38015
# iteracao: 1100 KKT violacoes: 39455
# iteracao: 1200 KKT violacoes: 38437
# iteracao: 1300 KKT violacoes: 35761
# iteracao: 1400 KKT violacoes: 35623
# iteracao: 1500 KKT violacoes: 35919
# iteracao: 1600 KKT violacoes: 28600
# iteracao: 1700 KKT violacoes: 32915
# iteracao: 1800 KKT violacoes: 30539
# iteracao: 1900 KKT violacoes: 29675
# iteracao: 2000 KKT violacoes: 27208
# iteracao: 2100 KKT violacoes: 19540
# iteracao: 2200 KKT violacoes: 17351
# iteracao: 2300 KKT violacoes: 13640
# iteracao: 2400 KKT violacoes: 7913
# iteracao: 2500 KKT violacoes: 9026
# iteracao: 2600 KKT violacoes: 3069
# fim do treino por fim das violacoes de KKT, total iteracoes: 2611
# Treino Acuracia:0.999530890838298
# Teste Acuracia:0.5873070325900515
# tempo treinamento 0:03:30.459434
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42172
# iteracao: 200 KKT violacoes: 41740
# iteracao: 300 KKT violacoes: 41166
# iteracao: 400 KKT violacoes: 41728
# iteracao: 500 KKT violacoes: 39676
# iteracao: 600 KKT violacoes: 41498
# iteracao: 700 KKT violacoes: 41053
# iteracao: 800 KKT violacoes: 39796
# iteracao: 900 KKT violacoes: 38826
# iteracao: 1000 KKT violacoes: 39450
# iteracao: 1100 KKT violacoes: 37246
# iteracao: 1200 KKT violacoes: 36035
# iteracao: 1300 KKT violacoes: 35949
# iteracao: 1400 KKT violacoes: 37411
# iteracao: 1500 KKT violacoes: 32751
# iteracao: 1600 KKT violacoes: 30670
# iteracao: 1700 KKT violacoes: 31028
# iteracao: 1800 KKT violacoes: 27692
# iteracao: 1900 KKT violacoes: 24454
# iteracao: 2000 KKT violacoes: 24684
# iteracao: 2100 KKT violacoes: 18094
# iteracao: 2200 KKT violacoes: 16106
# iteracao: 2300 KKT violacoes: 10917
# iteracao: 2400 KKT violacoes: 5022
# iteracao: 2500 KKT violacoes: 1243
# iteracao: 2600 KKT violacoes: 2124
# fim do treino por fim das violacoes de KKT, total iteracoes: 2678
# Treino Acuracia:0.999530890838298
# Teste Acuracia:0.5842195540308748
# tempo treinamento 0:03:37.709595
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42123
# iteracao: 200 KKT violacoes: 42024
# iteracao: 300 KKT violacoes: 41818
# iteracao: 400 KKT violacoes: 41436
# iteracao: 500 KKT violacoes: 40807
# iteracao: 600 KKT violacoes: 40939
# iteracao: 700 KKT violacoes: 40974
# iteracao: 800 KKT violacoes: 40742
# iteracao: 900 KKT violacoes: 40020
# iteracao: 1000 KKT violacoes: 39361
# iteracao: 1100 KKT violacoes: 39098
# iteracao: 1200 KKT violacoes: 36153
# iteracao: 1300 KKT violacoes: 38006
# iteracao: 1400 KKT violacoes: 37093
# iteracao: 1500 KKT violacoes: 32970
# iteracao: 1600 KKT violacoes: 35049
# iteracao: 1700 KKT violacoes: 32802
# iteracao: 1800 KKT violacoes: 27187
# iteracao: 1900 KKT violacoes: 29820
# iteracao: 2000 KKT violacoes: 25171
# iteracao: 2100 KKT violacoes: 19246
# iteracao: 2200 KKT violacoes: 17116
# iteracao: 2300 KKT violacoes: 11109
# iteracao: 2400 KKT violacoes: 7577
# iteracao: 2500 KKT violacoes: 5373
# iteracao: 2600 KKT violacoes: 1252
# fim do treino por fim das violacoes de KKT, total iteracoes: 2610
# Treino Acuracia:0.9995778017544683
# Teste Acuracia:0.5861921097770154
# tempo treinamento 0:03:31.149636
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42192
# iteracao: 200 KKT violacoes: 42015
# iteracao: 300 KKT violacoes: 41553
# iteracao: 400 KKT violacoes: 41770
# iteracao: 500 KKT violacoes: 40097
# iteracao: 600 KKT violacoes: 41105
# iteracao: 700 KKT violacoes: 40341
# iteracao: 800 KKT violacoes: 40133
# iteracao: 900 KKT violacoes: 40407
# iteracao: 1000 KKT violacoes: 39097
# iteracao: 1100 KKT violacoes: 38422
# iteracao: 1200 KKT violacoes: 37717
# iteracao: 1300 KKT violacoes: 36313
# iteracao: 1400 KKT violacoes: 37223
# iteracao: 1500 KKT violacoes: 36403
# iteracao: 1600 KKT violacoes: 35027
# iteracao: 1700 KKT violacoes: 33822
# iteracao: 1800 KKT violacoes: 29779
# iteracao: 1900 KKT violacoes: 27763
# iteracao: 2000 KKT violacoes: 26220
# iteracao: 2100 KKT violacoes: 22594
# iteracao: 2200 KKT violacoes: 16245
# iteracao: 2300 KKT violacoes: 12885
# iteracao: 2400 KKT violacoes: 7141
# iteracao: 2500 KKT violacoes: 1860
# iteracao: 2600 KKT violacoes: 334
# fim do treino por fim das violacoes de KKT, total iteracoes: 2698
# Treino Acuracia:0.9997889008772342
# Teste Acuracia:0.5884219554030875
# tempo treinamento 0:03:38.921478
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42064
# iteracao: 200 KKT violacoes: 42055
# iteracao: 300 KKT violacoes: 41755
# iteracao: 400 KKT violacoes: 41848
# iteracao: 500 KKT violacoes: 41699
# iteracao: 600 KKT violacoes: 41369
# iteracao: 700 KKT violacoes: 41305
# iteracao: 800 KKT violacoes: 40482
# iteracao: 900 KKT violacoes: 39186
# iteracao: 1000 KKT violacoes: 40165
# iteracao: 1100 KKT violacoes: 39357
# iteracao: 1200 KKT violacoes: 38508
# iteracao: 1300 KKT violacoes: 37228
# iteracao: 1400 KKT violacoes: 35712
# iteracao: 1500 KKT violacoes: 34530
# iteracao: 1600 KKT violacoes: 33357
# iteracao: 1700 KKT violacoes: 29611
# iteracao: 1800 KKT violacoes: 27212
# iteracao: 1900 KKT violacoes: 29658
# iteracao: 2000 KKT violacoes: 26104
# iteracao: 2100 KKT violacoes: 19479
# iteracao: 2200 KKT violacoes: 16259
# iteracao: 2300 KKT violacoes: 9884
# iteracao: 2400 KKT violacoes: 8653
# iteracao: 2500 KKT violacoes: 4922
# iteracao: 2600 KKT violacoes: 1063
# fim do treino por fim das violacoes de KKT, total iteracoes: 2623
# Treino Acuracia:0.9997185345029789
# Teste Acuracia:0.5892795883361921
# tempo treinamento 0:03:32.111428
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42150
# iteracao: 200 KKT violacoes: 42063
# iteracao: 300 KKT violacoes: 41867
# iteracao: 400 KKT violacoes: 41190
# iteracao: 500 KKT violacoes: 40625
# iteracao: 600 KKT violacoes: 41461
# iteracao: 700 KKT violacoes: 39867
# iteracao: 800 KKT violacoes: 41191
# iteracao: 900 KKT violacoes: 39885
# iteracao: 1000 KKT violacoes: 38924
# iteracao: 1100 KKT violacoes: 38376
# iteracao: 1200 KKT violacoes: 38003
# iteracao: 1300 KKT violacoes: 36280
# iteracao: 1400 KKT violacoes: 32554
# iteracao: 1500 KKT violacoes: 34042
# iteracao: 1600 KKT violacoes: 32735
# iteracao: 1700 KKT violacoes: 26638
# iteracao: 1800 KKT violacoes: 30730
# iteracao: 1900 KKT violacoes: 25214
# iteracao: 2000 KKT violacoes: 23236
# iteracao: 2100 KKT violacoes: 20732
# iteracao: 2200 KKT violacoes: 15570
# iteracao: 2300 KKT violacoes: 10472
# iteracao: 2400 KKT violacoes: 10181
# iteracao: 2500 KKT violacoes: 1283
# iteracao: 2600 KKT violacoes: 156
# iteracao: 2700 KKT violacoes: 1
# fim do treino por fim das violacoes de KKT, total iteracoes: 2715
# Treino Acuracia:0.9997185345029789
# Teste Acuracia:0.5877358490566038
# tempo treinamento 0:03:39.417163
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42196
# iteracao: 200 KKT violacoes: 42032
# iteracao: 300 KKT violacoes: 41943
# iteracao: 400 KKT violacoes: 40488
# iteracao: 500 KKT violacoes: 41012
# iteracao: 600 KKT violacoes: 40515
# iteracao: 700 KKT violacoes: 40132
# iteracao: 800 KKT violacoes: 39737
# iteracao: 900 KKT violacoes: 38375
# iteracao: 1000 KKT violacoes: 40255
# iteracao: 1100 KKT violacoes: 39406
# iteracao: 1200 KKT violacoes: 34827
# iteracao: 1300 KKT violacoes: 36184
# iteracao: 1400 KKT violacoes: 37750
# iteracao: 1500 KKT violacoes: 35946
# iteracao: 1600 KKT violacoes: 33921
# iteracao: 1700 KKT violacoes: 30434
# iteracao: 1800 KKT violacoes: 26800
# iteracao: 1900 KKT violacoes: 27332
# iteracao: 2000 KKT violacoes: 22569
# iteracao: 2100 KKT violacoes: 20185
# iteracao: 2200 KKT violacoes: 17335
# iteracao: 2300 KKT violacoes: 10824
# iteracao: 2400 KKT violacoes: 6236
# iteracao: 2500 KKT violacoes: 2721
# iteracao: 2600 KKT violacoes: 89
# fim do treino por fim das violacoes de KKT, total iteracoes: 2658
# Treino Acuracia:0.9996716235868086
# Teste Acuracia:0.5827615780445969
# tempo treinamento 0:03:35.202590
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 41948
# iteracao: 200 KKT violacoes: 42125
# iteracao: 300 KKT violacoes: 41491
# iteracao: 400 KKT violacoes: 41115
# iteracao: 500 KKT violacoes: 40301
# iteracao: 600 KKT violacoes: 40935
# iteracao: 700 KKT violacoes: 40121
# iteracao: 800 KKT violacoes: 40226
# iteracao: 900 KKT violacoes: 40699
# iteracao: 1000 KKT violacoes: 39090
# iteracao: 1100 KKT violacoes: 39092
# iteracao: 1200 KKT violacoes: 38492
# iteracao: 1300 KKT violacoes: 36374
# iteracao: 1400 KKT violacoes: 36499
# iteracao: 1500 KKT violacoes: 33040
# iteracao: 1600 KKT violacoes: 33152
# iteracao: 1700 KKT violacoes: 30057
# iteracao: 1800 KKT violacoes: 32054
# iteracao: 1900 KKT violacoes: 28461
# iteracao: 2000 KKT violacoes: 23024
# iteracao: 2100 KKT violacoes: 20080
# iteracao: 2200 KKT violacoes: 17128
# iteracao: 2300 KKT violacoes: 14946
# iteracao: 2400 KKT violacoes: 6199
# iteracao: 2500 KKT violacoes: 1415
# iteracao: 2600 KKT violacoes: 3613
# fim do treino por fim das violacoes de KKT, total iteracoes: 2697
# Treino Acuracia:0.9997889008772342
# Teste Acuracia:0.5879073756432247
# tempo treinamento 0:03:38.850706
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 41964
# iteracao: 200 KKT violacoes: 42078
# iteracao: 300 KKT violacoes: 41852
# iteracao: 400 KKT violacoes: 41258
# iteracao: 500 KKT violacoes: 40942
# iteracao: 600 KKT violacoes: 41436
# iteracao: 700 KKT violacoes: 40291
# iteracao: 800 KKT violacoes: 40576
# iteracao: 900 KKT violacoes: 39320
# iteracao: 1000 KKT violacoes: 39180
# iteracao: 1100 KKT violacoes: 39598
# iteracao: 1200 KKT violacoes: 37947
# iteracao: 1300 KKT violacoes: 38363
# iteracao: 1400 KKT violacoes: 35884
# iteracao: 1500 KKT violacoes: 36335
# iteracao: 1600 KKT violacoes: 34649
# iteracao: 1700 KKT violacoes: 32975
# iteracao: 1800 KKT violacoes: 29604
# iteracao: 1900 KKT violacoes: 29379
# iteracao: 2000 KKT violacoes: 26252
# iteracao: 2100 KKT violacoes: 18894
# iteracao: 2200 KKT violacoes: 18106
# iteracao: 2300 KKT violacoes: 12918
# iteracao: 2400 KKT violacoes: 6104
# iteracao: 2500 KKT violacoes: 3785
# iteracao: 2600 KKT violacoes: 3828
# iteracao: 2700 KKT violacoes: 24
# fim do treino por fim das violacoes de KKT, total iteracoes: 2701
# Treino Acuracia:0.9996950790448937
# Teste Acuracia:0.5806174957118353
# tempo treinamento 0:03:37.366774
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 41979
# iteracao: 200 KKT violacoes: 42029
# iteracao: 300 KKT violacoes: 41926
# iteracao: 400 KKT violacoes: 41726
# iteracao: 500 KKT violacoes: 41183
# iteracao: 600 KKT violacoes: 40659
# iteracao: 700 KKT violacoes: 40571
# iteracao: 800 KKT violacoes: 39645
# iteracao: 900 KKT violacoes: 39990
# iteracao: 1000 KKT violacoes: 38636
# iteracao: 1100 KKT violacoes: 38968
# iteracao: 1200 KKT violacoes: 38818
# iteracao: 1300 KKT violacoes: 38158
# iteracao: 1400 KKT violacoes: 37686
# iteracao: 1500 KKT violacoes: 36447
# iteracao: 1600 KKT violacoes: 31942
# iteracao: 1700 KKT violacoes: 33965
# iteracao: 1800 KKT violacoes: 27826
# iteracao: 1900 KKT violacoes: 24421
# iteracao: 2000 KKT violacoes: 25945
# iteracao: 2100 KKT violacoes: 19010
# iteracao: 2200 KKT violacoes: 17462
# iteracao: 2300 KKT violacoes: 11241
# iteracao: 2400 KKT violacoes: 5182
# iteracao: 2500 KKT violacoes: 6303
# iteracao: 2600 KKT violacoes: 63
# iteracao: 2700 KKT violacoes: 2
# fim do treino por fim das violacoes de KKT, total iteracoes: 2702
# Treino Acuracia:0.9996950790448937
# Teste Acuracia:0.5839622641509434
# tempo treinamento 0:03:37.337476
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42199
# iteracao: 200 KKT violacoes: 41622
# iteracao: 300 KKT violacoes: 40247
# iteracao: 400 KKT violacoes: 41632
# iteracao: 500 KKT violacoes: 40183
# iteracao: 600 KKT violacoes: 40949
# iteracao: 700 KKT violacoes: 41160
# iteracao: 800 KKT violacoes: 39720
# iteracao: 900 KKT violacoes: 39461
# iteracao: 1000 KKT violacoes: 38761
# iteracao: 1100 KKT violacoes: 37415
# iteracao: 1200 KKT violacoes: 38437
# iteracao: 1300 KKT violacoes: 36694
# iteracao: 1400 KKT violacoes: 36682
# iteracao: 1500 KKT violacoes: 35747
# iteracao: 1600 KKT violacoes: 33093
# iteracao: 1700 KKT violacoes: 33256
# iteracao: 1800 KKT violacoes: 32677
# iteracao: 1900 KKT violacoes: 25935
# iteracao: 2000 KKT violacoes: 25479
# iteracao: 2100 KKT violacoes: 19783
# iteracao: 2200 KKT violacoes: 16908
# iteracao: 2300 KKT violacoes: 13334
# iteracao: 2400 KKT violacoes: 9924
# iteracao: 2500 KKT violacoes: 5772
# iteracao: 2600 KKT violacoes: 78
# fim do treino por fim das violacoes de KKT, total iteracoes: 2675
# Treino Acuracia:0.9997419899610639
# Teste Acuracia:0.5915951972555746
# tempo treinamento 0:03:35.675090
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42071
# iteracao: 200 KKT violacoes: 42008
# iteracao: 300 KKT violacoes: 41911
# iteracao: 400 KKT violacoes: 41512
# iteracao: 500 KKT violacoes: 40353
# iteracao: 600 KKT violacoes: 40920
# iteracao: 700 KKT violacoes: 40076
# iteracao: 800 KKT violacoes: 40501
# iteracao: 900 KKT violacoes: 36995
# iteracao: 1000 KKT violacoes: 39911
# iteracao: 1100 KKT violacoes: 35922
# iteracao: 1200 KKT violacoes: 38753
# iteracao: 1300 KKT violacoes: 37718
# iteracao: 1400 KKT violacoes: 36332
# iteracao: 1500 KKT violacoes: 34770
# iteracao: 1600 KKT violacoes: 31366
# iteracao: 1700 KKT violacoes: 33501
# iteracao: 1800 KKT violacoes: 32336
# iteracao: 1900 KKT violacoes: 28842
# iteracao: 2000 KKT violacoes: 22979
# iteracao: 2100 KKT violacoes: 20977
# iteracao: 2200 KKT violacoes: 15398
# iteracao: 2300 KKT violacoes: 10346
# iteracao: 2400 KKT violacoes: 7758
# iteracao: 2500 KKT violacoes: 4345
# iteracao: 2600 KKT violacoes: 181
# fim do treino por fim das violacoes de KKT, total iteracoes: 2629
# Treino Acuracia:0.9997185345029789
# Teste Acuracia:0.5865351629502573
# tempo treinamento 0:03:32.225398
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 41950
# iteracao: 200 KKT violacoes: 41726
# iteracao: 300 KKT violacoes: 40590
# iteracao: 400 KKT violacoes: 41741
# iteracao: 500 KKT violacoes: 40478
# iteracao: 600 KKT violacoes: 41424
# iteracao: 700 KKT violacoes: 41052
# iteracao: 800 KKT violacoes: 39744
# iteracao: 900 KKT violacoes: 37761
# iteracao: 1000 KKT violacoes: 38291
# iteracao: 1100 KKT violacoes: 37603
# iteracao: 1200 KKT violacoes: 37721
# iteracao: 1300 KKT violacoes: 36428
# iteracao: 1400 KKT violacoes: 36783
# iteracao: 1500 KKT violacoes: 36440
# iteracao: 1600 KKT violacoes: 33096
# iteracao: 1700 KKT violacoes: 30646
# iteracao: 1800 KKT violacoes: 28928
# iteracao: 1900 KKT violacoes: 26396
# iteracao: 2000 KKT violacoes: 23200
# iteracao: 2100 KKT violacoes: 19698
# iteracao: 2200 KKT violacoes: 16546
# iteracao: 2300 KKT violacoes: 11774
# iteracao: 2400 KKT violacoes: 9853
# iteracao: 2500 KKT violacoes: 2827
# iteracao: 2600 KKT violacoes: 1513
# fim do treino por fim das violacoes de KKT, total iteracoes: 2665
# Treino Acuracia:0.9997185345029789
# Teste Acuracia:0.5891938250428816
# tempo treinamento 0:03:32.315842
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42161
# iteracao: 200 KKT violacoes: 42066
# iteracao: 300 KKT violacoes: 41913
# iteracao: 400 KKT violacoes: 41370
# iteracao: 500 KKT violacoes: 41337
# iteracao: 600 KKT violacoes: 40241
# iteracao: 700 KKT violacoes: 41123
# iteracao: 800 KKT violacoes: 39897
# iteracao: 900 KKT violacoes: 40503
# iteracao: 1000 KKT violacoes: 38303
# iteracao: 1100 KKT violacoes: 38062
# iteracao: 1200 KKT violacoes: 38411
# iteracao: 1300 KKT violacoes: 35832
# iteracao: 1400 KKT violacoes: 35939
# iteracao: 1500 KKT violacoes: 35734
# iteracao: 1600 KKT violacoes: 36166
# iteracao: 1700 KKT violacoes: 33234
# iteracao: 1800 KKT violacoes: 26897
# iteracao: 1900 KKT violacoes: 26176
# iteracao: 2000 KKT violacoes: 25751
# iteracao: 2100 KKT violacoes: 21907
# iteracao: 2200 KKT violacoes: 15074
# iteracao: 2300 KKT violacoes: 10387
# iteracao: 2400 KKT violacoes: 7302
# iteracao: 2500 KKT violacoes: 5690
# iteracao: 2600 KKT violacoes: 2838
# fim do treino por fim das violacoes de KKT, total iteracoes: 2673
# Treino Acuracia:0.999530890838298
# Teste Acuracia:0.5832761578044597
# tempo treinamento 0:03:33.583295
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42123
# iteracao: 200 KKT violacoes: 41476
# iteracao: 300 KKT violacoes: 41191
# iteracao: 400 KKT violacoes: 41521
# iteracao: 500 KKT violacoes: 39035
# iteracao: 600 KKT violacoes: 40343
# iteracao: 700 KKT violacoes: 40900
# iteracao: 800 KKT violacoes: 39833
# iteracao: 900 KKT violacoes: 40048
# iteracao: 1000 KKT violacoes: 39994
# iteracao: 1100 KKT violacoes: 38861
# iteracao: 1200 KKT violacoes: 38288
# iteracao: 1300 KKT violacoes: 37477
# iteracao: 1400 KKT violacoes: 34723
# iteracao: 1500 KKT violacoes: 35529
# iteracao: 1600 KKT violacoes: 33577
# iteracao: 1700 KKT violacoes: 33432
# iteracao: 1800 KKT violacoes: 28446
# iteracao: 1900 KKT violacoes: 25073
# iteracao: 2000 KKT violacoes: 24759
# iteracao: 2100 KKT violacoes: 18191
# iteracao: 2200 KKT violacoes: 15798
# iteracao: 2300 KKT violacoes: 11740
# iteracao: 2400 KKT violacoes: 4442
# iteracao: 2500 KKT violacoes: 2505
# iteracao: 2600 KKT violacoes: 523
# fim do treino por fim das violacoes de KKT, total iteracoes: 2647
# Treino Acuracia:0.9995778017544683
# Teste Acuracia:0.5882504288164665
# tempo treinamento 0:03:32.010929
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42147
# iteracao: 200 KKT violacoes: 41927
# iteracao: 300 KKT violacoes: 41283
# iteracao: 400 KKT violacoes: 40330
# iteracao: 500 KKT violacoes: 40704
# iteracao: 600 KKT violacoes: 41452
# iteracao: 700 KKT violacoes: 41198
# iteracao: 800 KKT violacoes: 39986
# iteracao: 900 KKT violacoes: 40428
# iteracao: 1000 KKT violacoes: 40087
# iteracao: 1100 KKT violacoes: 38265
# iteracao: 1200 KKT violacoes: 35153
# iteracao: 1300 KKT violacoes: 37786
# iteracao: 1400 KKT violacoes: 34328
# iteracao: 1500 KKT violacoes: 32421
# iteracao: 1600 KKT violacoes: 30841
# iteracao: 1700 KKT violacoes: 31895
# iteracao: 1800 KKT violacoes: 30657
# iteracao: 1900 KKT violacoes: 25850
# iteracao: 2000 KKT violacoes: 26068
# iteracao: 2100 KKT violacoes: 20410
# iteracao: 2200 KKT violacoes: 16612
# iteracao: 2300 KKT violacoes: 12265
# iteracao: 2400 KKT violacoes: 8943
# iteracao: 2500 KKT violacoes: 3570
# iteracao: 2600 KKT violacoes: 18
# fim do treino por fim das violacoes de KKT, total iteracoes: 2638
# Treino Acuracia:0.9996481681287236
# Teste Acuracia:0.589451114922813
# tempo treinamento 0:03:29.642274
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42148
# iteracao: 200 KKT violacoes: 41454
# iteracao: 300 KKT violacoes: 41931
# iteracao: 400 KKT violacoes: 41780
# iteracao: 500 KKT violacoes: 41466
# iteracao: 600 KKT violacoes: 41294
# iteracao: 700 KKT violacoes: 40245
# iteracao: 800 KKT violacoes: 40648
# iteracao: 900 KKT violacoes: 39962
# iteracao: 1000 KKT violacoes: 39795
# iteracao: 1100 KKT violacoes: 37755
# iteracao: 1200 KKT violacoes: 38419
# iteracao: 1300 KKT violacoes: 37490
# iteracao: 1400 KKT violacoes: 35772
# iteracao: 1500 KKT violacoes: 36089
# iteracao: 1600 KKT violacoes: 33703
# iteracao: 1700 KKT violacoes: 34311
# iteracao: 1800 KKT violacoes: 32140
# iteracao: 1900 KKT violacoes: 29024
# iteracao: 2000 KKT violacoes: 25360
# iteracao: 2100 KKT violacoes: 18822
# iteracao: 2200 KKT violacoes: 16047
# iteracao: 2300 KKT violacoes: 12529
# iteracao: 2400 KKT violacoes: 7566
# iteracao: 2500 KKT violacoes: 787
# iteracao: 2600 KKT violacoes: 82
# fim do treino por fim das violacoes de KKT, total iteracoes: 2681
# Treino Acuracia:0.9996481681287236
# Teste Acuracia:0.5893653516295025
# tempo treinamento 0:03:33.716497
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42086
# iteracao: 200 KKT violacoes: 42102
# iteracao: 300 KKT violacoes: 41116
# iteracao: 400 KKT violacoes: 41469
# iteracao: 500 KKT violacoes: 41400
# iteracao: 600 KKT violacoes: 41302
# iteracao: 700 KKT violacoes: 41182
# iteracao: 800 KKT violacoes: 40882
# iteracao: 900 KKT violacoes: 40162
# iteracao: 1000 KKT violacoes: 39910
# iteracao: 1100 KKT violacoes: 37998
# iteracao: 1200 KKT violacoes: 37238
# iteracao: 1300 KKT violacoes: 35480
# iteracao: 1400 KKT violacoes: 34592
# iteracao: 1500 KKT violacoes: 34537
# iteracao: 1600 KKT violacoes: 29248
# iteracao: 1700 KKT violacoes: 30734
# iteracao: 1800 KKT violacoes: 31078
# iteracao: 1900 KKT violacoes: 25502
# iteracao: 2000 KKT violacoes: 23118
# iteracao: 2100 KKT violacoes: 22122
# iteracao: 2200 KKT violacoes: 16952
# iteracao: 2300 KKT violacoes: 12321
# iteracao: 2400 KKT violacoes: 9040
# iteracao: 2500 KKT violacoes: 1311
# iteracao: 2600 KKT violacoes: 654
# fim do treino por fim das violacoes de KKT, total iteracoes: 2662
# Treino Acuracia:0.9997419899610639
# Teste Acuracia:0.580360205831904
# tempo treinamento 0:03:33.046044
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42118
# iteracao: 200 KKT violacoes: 41949
# iteracao: 300 KKT violacoes: 41788
# iteracao: 400 KKT violacoes: 40091
# iteracao: 500 KKT violacoes: 41533
# iteracao: 600 KKT violacoes: 40433
# iteracao: 700 KKT violacoes: 41205
# iteracao: 800 KKT violacoes: 40804
# iteracao: 900 KKT violacoes: 40323
# iteracao: 1000 KKT violacoes: 39253
# iteracao: 1100 KKT violacoes: 37875
# iteracao: 1200 KKT violacoes: 38336
# iteracao: 1300 KKT violacoes: 35583
# iteracao: 1400 KKT violacoes: 36419
# iteracao: 1500 KKT violacoes: 35995
# iteracao: 1600 KKT violacoes: 29595
# iteracao: 1700 KKT violacoes: 30993
# iteracao: 1800 KKT violacoes: 31410
# iteracao: 1900 KKT violacoes: 28485
# iteracao: 2000 KKT violacoes: 23825
# iteracao: 2100 KKT violacoes: 21044
# iteracao: 2200 KKT violacoes: 17070
# iteracao: 2300 KKT violacoes: 12351
# iteracao: 2400 KKT violacoes: 5623
# iteracao: 2500 KKT violacoes: 4599
# iteracao: 2600 KKT violacoes: 1106
# iteracao: 2700 KKT violacoes: 1
# fim do treino por fim das violacoes de KKT, total iteracoes: 2714
# Treino Acuracia:0.9996481681287236
# Teste Acuracia:0.5833619210977702
# tempo treinamento 0:03:37.662311
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42041
# iteracao: 200 KKT violacoes: 42003
# iteracao: 300 KKT violacoes: 41712
# iteracao: 400 KKT violacoes: 41162
# iteracao: 500 KKT violacoes: 41471
# iteracao: 600 KKT violacoes: 40667
# iteracao: 700 KKT violacoes: 41195
# iteracao: 800 KKT violacoes: 40733
# iteracao: 900 KKT violacoes: 40223
# iteracao: 1000 KKT violacoes: 39698
# iteracao: 1100 KKT violacoes: 38842
# iteracao: 1200 KKT violacoes: 38285
# iteracao: 1300 KKT violacoes: 37915
# iteracao: 1400 KKT violacoes: 34362
# iteracao: 1500 KKT violacoes: 35409
# iteracao: 1600 KKT violacoes: 31487
# iteracao: 1700 KKT violacoes: 33372
# iteracao: 1800 KKT violacoes: 32187
# iteracao: 1900 KKT violacoes: 29343
# iteracao: 2000 KKT violacoes: 21439
# iteracao: 2100 KKT violacoes: 21323
# iteracao: 2200 KKT violacoes: 17217
# iteracao: 2300 KKT violacoes: 14239
# iteracao: 2400 KKT violacoes: 7215
# iteracao: 2500 KKT violacoes: 2310
# iteracao: 2600 KKT violacoes: 347
# fim do treino por fim das violacoes de KKT, total iteracoes: 2630
# Treino Acuracia:0.9996716235868086
# Teste Acuracia:0.5909090909090909
# tempo treinamento 0:03:30.295482
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42171
# iteracao: 200 KKT violacoes: 42066
# iteracao: 300 KKT violacoes: 41450
# iteracao: 400 KKT violacoes: 40919
# iteracao: 500 KKT violacoes: 41293
# iteracao: 600 KKT violacoes: 41233
# iteracao: 700 KKT violacoes: 38604
# iteracao: 800 KKT violacoes: 40375
# iteracao: 900 KKT violacoes: 40343
# iteracao: 1000 KKT violacoes: 40012
# iteracao: 1100 KKT violacoes: 38395
# iteracao: 1200 KKT violacoes: 37492
# iteracao: 1300 KKT violacoes: 33286
# iteracao: 1400 KKT violacoes: 36692
# iteracao: 1500 KKT violacoes: 33448
# iteracao: 1600 KKT violacoes: 35196
# iteracao: 1700 KKT violacoes: 32768
# iteracao: 1800 KKT violacoes: 31931
# iteracao: 1900 KKT violacoes: 27847
# iteracao: 2000 KKT violacoes: 27113
# iteracao: 2100 KKT violacoes: 19968
# iteracao: 2200 KKT violacoes: 16926
# iteracao: 2300 KKT violacoes: 15379
# iteracao: 2400 KKT violacoes: 6812
# iteracao: 2500 KKT violacoes: 4627
# iteracao: 2600 KKT violacoes: 5669
# iteracao: 2700 KKT violacoes: 3
# fim do treino por fim das violacoes de KKT, total iteracoes: 2740
# Treino Acuracia:0.9996247126706385
# Teste Acuracia:0.5903087478559177
# tempo treinamento 0:03:37.938777
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42129
# iteracao: 200 KKT violacoes: 42095
# iteracao: 300 KKT violacoes: 41973
# iteracao: 400 KKT violacoes: 41297
# iteracao: 500 KKT violacoes: 41095
# iteracao: 600 KKT violacoes: 41330
# iteracao: 700 KKT violacoes: 41151
# iteracao: 800 KKT violacoes: 40813
# iteracao: 900 KKT violacoes: 39948
# iteracao: 1000 KKT violacoes: 39656
# iteracao: 1100 KKT violacoes: 36915
# ...
# Treino Acuracia:0.9995778017544683
# Teste Acuracia:0.5916809605488851
# tempo treinamento 0:03:29.744374
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42181
# iteracao: 200 KKT violacoes: 42025
# iteracao: 300 KKT violacoes: 41322
# iteracao: 400 KKT violacoes: 41716
# iteracao: 500 KKT violacoes: 41599
# iteracao: 600 KKT violacoes: 40844
# iteracao: 700 KKT violacoes: 40607
# iteracao: 800 KKT violacoes: 40410
# iteracao: 900 KKT violacoes: 40265
# iteracao: 1000 KKT violacoes: 39301
# iteracao: 1100 KKT violacoes: 36163
# iteracao: 1200 KKT violacoes: 38300
# iteracao: 1300 KKT violacoes: 36415
# iteracao: 1400 KKT violacoes: 32993
# iteracao: 1500 KKT violacoes: 33801
# iteracao: 1600 KKT violacoes: 34446
# iteracao: 1700 KKT violacoes: 32186
# iteracao: 1800 KKT violacoes: 31894
# iteracao: 1900 KKT violacoes: 26285
# iteracao: 2000 KKT violacoes: 22575
# iteracao: 2100 KKT violacoes: 19035
# iteracao: 2200 KKT violacoes: 16283
# iteracao: 2300 KKT violacoes: 12899
# iteracao: 2400 KKT violacoes: 9186
# iteracao: 2500 KKT violacoes: 6349
# iteracao: 2600 KKT violacoes: 125
# fim do treino por fim das violacoes de KKT, total iteracoes: 2661
# Treino Acuracia:0.999765445419149
# Teste Acuracia:0.5948542024013722
# tempo treinamento 0:03:29.366130
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42047
# iteracao: 200 KKT violacoes: 41080
# iteracao: 300 KKT violacoes: 41905
# iteracao: 400 KKT violacoes: 40935
# iteracao: 500 KKT violacoes: 40750
# iteracao: 600 KKT violacoes: 41231
# iteracao: 700 KKT violacoes: 40712
# iteracao: 800 KKT violacoes: 40352
# iteracao: 900 KKT violacoes: 39557
# iteracao: 1000 KKT violacoes: 39938
# iteracao: 1100 KKT violacoes: 36432
# iteracao: 1200 KKT violacoes: 38652
# iteracao: 1300 KKT violacoes: 37909
# iteracao: 1400 KKT violacoes: 37558
# iteracao: 1500 KKT violacoes: 33897
# iteracao: 1600 KKT violacoes: 32443
# iteracao: 1700 KKT violacoes: 29045
# iteracao: 1800 KKT violacoes: 29494
# iteracao: 1900 KKT violacoes: 28569
# iteracao: 2000 KKT violacoes: 22360
# iteracao: 2100 KKT violacoes: 19664
# iteracao: 2200 KKT violacoes: 15877
# iteracao: 2300 KKT violacoes: 13259
# iteracao: 2400 KKT violacoes: 11775
# iteracao: 2500 KKT violacoes: 2644
# iteracao: 2600 KKT violacoes: 230
# fim do treino por fim das violacoes de KKT, total iteracoes: 2665
# Treino Acuracia:0.9996012572125533
# Teste Acuracia:0.5830188679245283
# tempo treinamento 0:03:30.390839
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42146
# iteracao: 200 KKT violacoes: 42138
# iteracao: 300 KKT violacoes: 42056
# iteracao: 400 KKT violacoes: 41713
# iteracao: 500 KKT violacoes: 41612
# iteracao: 600 KKT violacoes: 41305
# iteracao: 700 KKT violacoes: 41227
# iteracao: 800 KKT violacoes: 40902
# iteracao: 900 KKT violacoes: 39839
# iteracao: 1000 KKT violacoes: 40173
# iteracao: 1100 KKT violacoes: 37699
# iteracao: 1200 KKT violacoes: 38738
# iteracao: 1300 KKT violacoes: 34130
# iteracao: 1400 KKT violacoes: 35988
# iteracao: 1500 KKT violacoes: 35967
# iteracao: 1600 KKT violacoes: 31072
# iteracao: 1700 KKT violacoes: 29277
# iteracao: 1800 KKT violacoes: 29081
# iteracao: 1900 KKT violacoes: 29321
# iteracao: 2000 KKT violacoes: 24286
# iteracao: 2100 KKT violacoes: 19082
# iteracao: 2200 KKT violacoes: 16112
# iteracao: 2300 KKT violacoes: 11445
# iteracao: 2400 KKT violacoes: 4596
# iteracao: 2500 KKT violacoes: 1242
# iteracao: 2600 KKT violacoes: 3656
# fim do treino por fim das violacoes de KKT, total iteracoes: 2696
# Treino Acuracia:0.9998123563353192
# Teste Acuracia:0.584819897084048
# tempo treinamento 0:03:35.045398
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 41947
# iteracao: 200 KKT violacoes: 41467
# iteracao: 300 KKT violacoes: 41565
# iteracao: 400 KKT violacoes: 41612
# iteracao: 500 KKT violacoes: 40941
# iteracao: 600 KKT violacoes: 40391
# iteracao: 700 KKT violacoes: 39859
# iteracao: 800 KKT violacoes: 39626
# iteracao: 900 KKT violacoes: 38677
# iteracao: 1000 KKT violacoes: 39246
# iteracao: 1100 KKT violacoes: 37168
# iteracao: 1200 KKT violacoes: 37530
# iteracao: 1300 KKT violacoes: 36257
# iteracao: 1400 KKT violacoes: 37304
# iteracao: 1500 KKT violacoes: 36571
# iteracao: 1600 KKT violacoes: 30667
# iteracao: 1700 KKT violacoes: 33319
# iteracao: 1800 KKT violacoes: 27302
# iteracao: 1900 KKT violacoes: 26142
# iteracao: 2000 KKT violacoes: 24174
# iteracao: 2100 KKT violacoes: 22752
# iteracao: 2200 KKT violacoes: 16554
# iteracao: 2300 KKT violacoes: 11502
# iteracao: 2400 KKT violacoes: 10556
# iteracao: 2500 KKT violacoes: 1719
# iteracao: 2600 KKT violacoes: 9
# fim do treino por fim das violacoes de KKT, total iteracoes: 2632
# Treino Acuracia:0.9998358117934043
# Teste Acuracia:0.5783876500857633
# tempo treinamento 0:03:34.161648
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42241
# iteracao: 200 KKT violacoes: 41980
# iteracao: 300 KKT violacoes: 41995
# iteracao: 400 KKT violacoes: 41856
# iteracao: 500 KKT violacoes: 41473
# iteracao: 600 KKT violacoes: 41121
# iteracao: 700 KKT violacoes: 40803
# iteracao: 800 KKT violacoes: 39096
# iteracao: 900 KKT violacoes: 40103
# iteracao: 1000 KKT violacoes: 38362
# iteracao: 1100 KKT violacoes: 37157
# iteracao: 1200 KKT violacoes: 35387
# iteracao: 1300 KKT violacoes: 36299
# iteracao: 1400 KKT violacoes: 37285
# iteracao: 1500 KKT violacoes: 34526
# iteracao: 1600 KKT violacoes: 30737
# iteracao: 1700 KKT violacoes: 33488
# iteracao: 1800 KKT violacoes: 28737
# iteracao: 1900 KKT violacoes: 27028
# iteracao: 2000 KKT violacoes: 27279
# iteracao: 2100 KKT violacoes: 19702
# iteracao: 2200 KKT violacoes: 16814
# iteracao: 2300 KKT violacoes: 13503
# iteracao: 2400 KKT violacoes: 10240
# iteracao: 2500 KKT violacoes: 2993
# iteracao: 2600 KKT violacoes: 1889
# fim do treino por fim das violacoes de KKT, total iteracoes: 2694
# Treino Acuracia:0.9995543462963832
# Teste Acuracia:0.5778730703259005
# tempo treinamento 0:03:37.649342
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42171
# iteracao: 200 KKT violacoes: 41991
# iteracao: 300 KKT violacoes: 41167
# iteracao: 400 KKT violacoes: 41723
# iteracao: 500 KKT violacoes: 41776
# iteracao: 600 KKT violacoes: 41493
# iteracao: 700 KKT violacoes: 41143
# iteracao: 800 KKT violacoes: 40833
# iteracao: 900 KKT violacoes: 38907
# iteracao: 1000 KKT violacoes: 37682
# iteracao: 1100 KKT violacoes: 39355
# iteracao: 1200 KKT violacoes: 36550
# iteracao: 1300 KKT violacoes: 38327
# iteracao: 1400 KKT violacoes: 37263
# iteracao: 1500 KKT violacoes: 36226
# iteracao: 1600 KKT violacoes: 32107
# iteracao: 1700 KKT violacoes: 27772
# iteracao: 1800 KKT violacoes: 28632
# iteracao: 1900 KKT violacoes: 27517
# iteracao: 2000 KKT violacoes: 26646
# iteracao: 2100 KKT violacoes: 19550
# iteracao: 2200 KKT violacoes: 17225
# iteracao: 2300 KKT violacoes: 10728
# iteracao: 2400 KKT violacoes: 6373
# iteracao: 2500 KKT violacoes: 3361
# iteracao: 2600 KKT violacoes: 3236
# fim do treino por fim das violacoes de KKT, total iteracoes: 2667
# Treino Acuracia:0.9996012572125533
# Teste Acuracia:0.583876500857633
# tempo treinamento 0:03:36.215287
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42129
# iteracao: 200 KKT violacoes: 41840
# iteracao: 300 KKT violacoes: 40325
# iteracao: 400 KKT violacoes: 41955
# iteracao: 500 KKT violacoes: 41771
# iteracao: 600 KKT violacoes: 41374
# iteracao: 700 KKT violacoes: 40755
# iteracao: 800 KKT violacoes: 40891
# iteracao: 900 KKT violacoes: 40136
# iteracao: 1000 KKT violacoes: 39837
# iteracao: 1100 KKT violacoes: 38692
# iteracao: 1200 KKT violacoes: 38588
# iteracao: 1300 KKT violacoes: 37589
# iteracao: 1400 KKT violacoes: 36973
# iteracao: 1500 KKT violacoes: 34831
# iteracao: 1600 KKT violacoes: 34213
# iteracao: 1700 KKT violacoes: 32631
# iteracao: 1800 KKT violacoes: 32004
# iteracao: 1900 KKT violacoes: 29270
# iteracao: 2000 KKT violacoes: 26561
# iteracao: 2100 KKT violacoes: 19954
# iteracao: 2200 KKT violacoes: 17515
# iteracao: 2300 KKT violacoes: 10230
# iteracao: 2400 KKT violacoes: 9961
# iteracao: 2500 KKT violacoes: 1189
# iteracao: 2600 KKT violacoes: 27
# fim do treino por fim das violacoes de KKT, total iteracoes: 2650
# Treino Acuracia:0.9997419899610639
# Teste Acuracia:0.5839622641509434
# tempo treinamento 0:03:34.900493
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42141
# iteracao: 200 KKT violacoes: 41570
# iteracao: 300 KKT violacoes: 41334
# iteracao: 400 KKT violacoes: 39769
# iteracao: 500 KKT violacoes: 41611
# iteracao: 600 KKT violacoes: 40741
# iteracao: 700 KKT violacoes: 40396
# iteracao: 800 KKT violacoes: 41010
# iteracao: 900 KKT violacoes: 40060
# iteracao: 1000 KKT violacoes: 38003
# iteracao: 1100 KKT violacoes: 36463
# iteracao: 1200 KKT violacoes: 38274
# iteracao: 1300 KKT violacoes: 36635
# iteracao: 1400 KKT violacoes: 36446
# iteracao: 1500 KKT violacoes: 36375
# iteracao: 1600 KKT violacoes: 33505
# iteracao: 1700 KKT violacoes: 32766
# iteracao: 1800 KKT violacoes: 27097
# iteracao: 1900 KKT violacoes: 30056
# iteracao: 2000 KKT violacoes: 24048
# iteracao: 2100 KKT violacoes: 22391
# iteracao: 2200 KKT violacoes: 16515
# iteracao: 2300 KKT violacoes: 10743
# iteracao: 2400 KKT violacoes: 5173
# iteracao: 2500 KKT violacoes: 6338
# iteracao: 2600 KKT violacoes: 221
# fim do treino por fim das violacoes de KKT, total iteracoes: 2678
# Treino Acuracia:0.999765445419149
# Teste Acuracia:0.587221269296741
# tempo treinamento 0:03:37.005264
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42060
# iteracao: 200 KKT violacoes: 42035
# iteracao: 300 KKT violacoes: 40929
# iteracao: 400 KKT violacoes: 40864
# iteracao: 500 KKT violacoes: 41212
# iteracao: 600 KKT violacoes: 41537
# iteracao: 700 KKT violacoes: 41278
# iteracao: 800 KKT violacoes: 39587
# iteracao: 900 KKT violacoes: 37528
# iteracao: 1000 KKT violacoes: 39064
# iteracao: 1100 KKT violacoes: 39058
# iteracao: 1200 KKT violacoes: 34410
# iteracao: 1300 KKT violacoes: 37776
# iteracao: 1400 KKT violacoes: 37023
# iteracao: 1500 KKT violacoes: 36156
# iteracao: 1600 KKT violacoes: 34514
# iteracao: 1700 KKT violacoes: 30256
# iteracao: 1800 KKT violacoes: 31618
# iteracao: 1900 KKT violacoes: 26798
# iteracao: 2000 KKT violacoes: 26346
# iteracao: 2100 KKT violacoes: 21523
# iteracao: 2200 KKT violacoes: 17719
# iteracao: 2300 KKT violacoes: 13295
# iteracao: 2400 KKT violacoes: 10297
# iteracao: 2500 KKT violacoes: 6684
# iteracao: 2600 KKT violacoes: 171
# fim do treino por fim das violacoes de KKT, total iteracoes: 2689
# Treino Acuracia:0.9997185345029789
# Teste Acuracia:0.5955403087478559
# tempo treinamento 0:03:38.760850
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42170
# iteracao: 200 KKT violacoes: 41436
# iteracao: 300 KKT violacoes: 40251
# iteracao: 400 KKT violacoes: 41388
# iteracao: 500 KKT violacoes: 41599
# iteracao: 600 KKT violacoes: 40963
# iteracao: 700 KKT violacoes: 37705
# iteracao: 800 KKT violacoes: 40894
# iteracao: 900 KKT violacoes: 40253
# iteracao: 1000 KKT violacoes: 38306
# iteracao: 1100 KKT violacoes: 36550
# iteracao: 1200 KKT violacoes: 38552
# iteracao: 1300 KKT violacoes: 38170
# iteracao: 1400 KKT violacoes: 37146
# iteracao: 1500 KKT violacoes: 31408
# iteracao: 1600 KKT violacoes: 33586
# iteracao: 1700 KKT violacoes: 29278
# iteracao: 1800 KKT violacoes: 27966
# iteracao: 1900 KKT violacoes: 24377
# iteracao: 2000 KKT violacoes: 26850
# iteracao: 2100 KKT violacoes: 20150
# iteracao: 2200 KKT violacoes: 17539
# iteracao: 2300 KKT violacoes: 11392
# iteracao: 2400 KKT violacoes: 5950
# iteracao: 2500 KKT violacoes: 1560
# iteracao: 2600 KKT violacoes: 261
# iteracao: 2700 KKT violacoes: 380
# fim do treino por fim das violacoes de KKT, total iteracoes: 2701
# Treino Acuracia:0.9996481681287236
# Teste Acuracia:0.5945969125214409
# tempo treinamento 0:03:38.378166
# instanciado um svm
# svm.fit
# X.shape (42634, 576)
# Y.shape (42634, 1)
# config: {'kkttol': 0.05, 'chunksize': 8000, 'bias': [], 'sv': [], 'svcoeff': [], 'normalw': [], 'C': 2, 'h': 0, 'debug': True, 'alphatol': 0.01, 'SVThresh': 0, 'qpsize': 256, 'logs': [], 'configs': {}, 'kernelpar': 1.6, 'randomWS': True}
# iteracao: 0 KKT violacoes: 42634
# iteracao: 100 KKT violacoes: 42154
# iteracao: 200 KKT violacoes: 42069
# iteracao: 300 KKT violacoes: 41897
# iteracao: 400 KKT violacoes: 41913
# iteracao: 500 KKT violacoes: 41489
# iteracao: 600 KKT violacoes: 41371
# iteracao: 700 KKT violacoes: 41024
# iteracao: 800 KKT violacoes: 40798
# iteracao: 900 KKT violacoes: 40132
# iteracao: 1000 KKT violacoes: 40113
# iteracao: 1100 KKT violacoes: 38236
# iteracao: 1200 KKT violacoes: 38306
# iteracao: 1300 KKT violacoes: 37263
# iteracao: 1400 KKT violacoes: 37175
# iteracao: 1500 KKT violacoes: 33571
# iteracao: 1600 KKT violacoes: 34385
# iteracao: 1700 KKT violacoes: 30429
# iteracao: 1800 KKT violacoes: 26969
# iteracao: 1900 KKT violacoes: 27095
# iteracao: 2000 KKT violacoes: 22944
# iteracao: 2100 KKT violacoes: 19082
# iteracao: 2200 KKT violacoes: 16527
# iteracao: 2300 KKT violacoes: 12568
# iteracao: 2400 KKT violacoes: 7400
# iteracao: 2500 KKT violacoes: 5739
# iteracao: 2600 KKT violacoes: 564
# fim do treino por fim das violacoes de KKT, total iteracoes: 2662
# Treino Acuracia:0.9998592672514894
# Teste Acuracia:0.5880789022298456
# tempo treinamento 0:03:35.721030
# ecoc: acuracia treino 0.999695
# ecoc: acuracia teste 0.102573
# tempo treino_svm_total: 3:06:05.390461
# fim treino_svm_total

# %%
# import logging
# logging.basicConfig(filename="svm_workflow_lbp.py.log", 
#                     format='%(asctime)s %(message)s', 
#                     level=logging.INFO)
# logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
# dt_lbp = dataprep(hdf5_path="/content/drive/Shareddrives/grupo_estudos/hdf5/lbp_grid_total",
#                              max_artists=32, lbp=True)

# dt_lbp.load_hdf5()
# dt_lbp.get_dictionary_artists()
# dt_lbp.get_dictionary_kfold_test()
# dt_lbp.get_dictionary_moc_ecoc_artists(ecoc=1)

# config = {}
# config['kkttol'] = 5e-2
# config['chunksize'] = 8000
# config['bias'] = []
# config['sv'] = []
# config['svcoeff'] = []
# config['normalw'] = []
# config['C'] = 10
# config['h'] = 0
# config['debug'] = True
# config['alphatol'] = 1e-2
# config['SVThresh'] = 0
# config['qpsize'] = 256
# config['logs'] = []
# config['configs'] = {}
# config['kernelpar'] = 1
# config['randomWS'] = True

# treino_svm_total(dt_lbp, config)
# kfold_cross_validation(dt_lbp, config)
